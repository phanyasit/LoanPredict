# %%
'''from google.colab import drive
drive.mount('/content/drive')'''
# Out:
# "from google.colab import drive\ndrive.mount('/content/drive')"

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib
import seaborn as sns
import datetime
import matplotlib as mpl
fp = mpl.font_manager.FontProperties(family='Tahoma',size=13)

# %matplotlib inline

# %% [markdown]
# # Import Data
#
# แปลง DOB และ System Car Code Date ให้เป็น วัน

# %%
#df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IS/chaiyo-is2.csv", parse_dates=['DOB','System CAR Code Date'])
df = pd.read_excel('Data20230120.xlsx', parse_dates=['DOB','System CAR Code Date'])
df.head()
# Out:
#   Application Number  Principal Approve Amount  Principal Amount  \
# 0  25651226INSI00001                    7500.0              0.00
# 1  25650620ULMB00004                   20000.0          13492.22
# 2  25650620ULCR00002                  130000.0         125931.40
# 3  25650621ULMB00001                   70000.0          60867.83
# 4  25650621ULMB00011                    3000.0           1585.66
#
#    Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 0                            12      M 1992-12-05          พนักงานบริษัท
# 1                            12      M 1986-08-15                  อื่นๆ
# 2                            60      F 1996-04-30                  อื่นๆ
# 3                            36      M 1979-04-01                  อื่นๆ
# 4                            13      M 1967-05-04          STREET VENDOR
#
#    Total Income Amount (Month) Collateral Type Code Vehicle Brand  \
# 0                     10000.00                   PU        TOYOTA
# 1                     25000.09                   MC         HONDA
# 2                     15000.00                  CAR         HONDA
# 3                     20000.00                   MC        YAMAHA
# 4                     30000.00                   MC         HONDA
#
#    Vehicle Model  Vehicle Release Year Vehicle Sub Model  Evaluation Amount  \
# 0  SPORT CRUISER                  2002                EP             225500
# 1        PCX 160                  2018                BV              64500
# 2          CIVIC                  2005                DK             220500
# 3      N-MAX 155                  2021                CE              81500
# 4     WAVE 125 I                  2010                AY              20000
#
#   System CAR Code (Daily) System CAR Code Date Final CAR Code Previous Month  \
# 0                      S1           2022-12-26                            S1
# 1                      S1           2022-06-20                            S1
# 2                      S1           2022-06-20                            S1
# 3                      S1           2022-06-21                            S1
# 4                      S1           2022-06-21                            S1
#
#    Day Past Due (Aging)     Application Status
# 0                     4  APPLICATION_COMPLETED
# 1                     0  APPLICATION_COMPLETED
# 2                     0  APPLICATION_COMPLETED
# 3                     0  APPLICATION_COMPLETED
# 4                     0  APPLICATION_COMPLETED

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53496 entries, 0 to 53495
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Application Number             53496 non-null  object
#  1   Principal Approve Amount       53496 non-null  float64
#  2   Principal Amount               53496 non-null  float64
#  3   Repayment Tenor Month Number   53496 non-null  int64
#  4   Gender                         53496 non-null  object
#  5   DOB                            53496 non-null  datetime64[ns]
#  6   Occupation Description         53496 non-null  object
#  7   Total Income Amount (Month)    53496 non-null  float64
#  8   Collateral Type Code           53496 non-null  object
#  9   Vehicle Brand                  53496 non-null  object
#  10  Vehicle Model                  53496 non-null  object
#  11  Vehicle Release Year           53496 non-null  int64
#  12  Vehicle Sub Model              53496 non-null  object
#  13  Evaluation Amount              53496 non-null  int64
#  14  System CAR Code (Daily)        53496 non-null  object
#  15  System CAR Code Date           53496 non-null  datetime64[ns]
#  16  Final CAR Code Previous Month  53496 non-null  object
#  17  Day Past Due (Aging)           53496 non-null  int64
#  18  Application Status             53496 non-null  object
# dtypes: datetime64[ns](2), float64(3), int64(4), object(10)
# memory usage: 7.8+ MB

# %%
df.describe().round(2)
# Out:
#        Principal Approve Amount  Principal Amount  \
# count                  53496.00          53496.00
# mean                  101640.79          98746.29
# std                   101697.95         101152.59
# min                     3000.00          -2253.34
# 25%                    26000.00          24900.00
# 50%                    48000.00          40884.99
# 75%                   165000.00         160000.00
# max                  2000000.00        2000000.00
#
#        Repayment Tenor Month Number  Total Income Amount (Month)  \
# count                      53496.00                     53496.00
# mean                          39.39                     25084.92
# std                           17.98                    114036.90
# min                            1.00                         0.00
# 25%                           24.00                     15000.00
# 50%                           36.00                     20000.00
# 75%                           60.00                     30000.00
# max                          120.00                  20000000.00
#
#        Vehicle Release Year  Evaluation Amount  Day Past Due (Aging)
# count              53496.00           53496.00              53496.00
# mean                2012.50          164745.58                  1.13
# std                    5.52          159732.24                  7.42
# min                 1976.00            5000.00                  0.00
# 25%                 2008.00           38900.00                  0.00
# 50%                 2013.00          117000.00                  0.00
# 75%                 2017.00          261125.00                  0.00
# max                 2022.00         3282500.00                147.00

# %% [markdown]
# # Data Preparation

# %% [markdown]
#  ##แปลงชื่อ Columns และ แปลง DOB เป็น อายุ

# %%
df.rename(columns={'Day Past Due (Aging)':'DPD'}, inplace=True)
df['age'] = pd.to_datetime('today').year - df.DOB.dt.year

# %% [markdown]
# ##คำนวณ % ของค่าว่าง

# %%
missing = df.isnull().sum()
missing
# Out:
# Application Number               0
# Principal Approve Amount         0
# Principal Amount                 0
# Repayment Tenor Month Number     0
# Gender                           0
# DOB                              0
# Occupation Description           0
# Total Income Amount (Month)      0
# Collateral Type Code             0
# Vehicle Brand                    0
# Vehicle Model                    0
# Vehicle Release Year             0
# Vehicle Sub Model                0
# Evaluation Amount                0
# System CAR Code (Daily)          0
# System CAR Code Date             0
# Final CAR Code Previous Month    0
# DPD                              0
# Application Status               0
# age                              0
# dtype: int64

# %%
missing_columns = list(missing[missing > 0].index)
missing_columns
# Out:
# []

# %%
total_missing = missing[missing > 0]
total_missing
# Out:
# Series([], dtype: int64)

# %%
missing_df = pd.DataFrame(total_missing, columns=['number_of_missing_values'])
missing_df
# Out:
# Empty DataFrame
# Columns: [number_of_missing_values]
# Index: []

# %%
missing_df['percent'] = total_missing * 100 / len(df)
missing_df
# Out:
# Empty DataFrame
# Columns: [number_of_missing_values, percent]
# Index: []

# %%
#df.dropna(subset=['Collateral Type Code','Vehicle Brand','Vehicle Model','Vehicle Release Year','Vehicle Sub Model','Evaluation Amount'], inplace=True)

# %%
#df[ (df['Collateral Type Code'] != 'CAR')&(df['Collateral Type Code'] != 'PU')&(df['Collateral Type Code'] != 'MC')]

# %%
indexApp = df[(df['Collateral Type Code'] == 'OTH')].index
df.drop(indexApp , inplace=True)

# %%
df.shape
# Out:
# (53496, 20)

# %%
#เพิ่ม column อายุรถ
df['Vehicle Age'] = pd.to_datetime('today').year - df['Vehicle Release Year']
df
# Out:
#       Application Number  Principal Approve Amount  Principal Amount  \
# 0      25651226INSI00001                    7500.0              0.00
# 1      25650620ULMB00004                   20000.0          13492.22
# 2      25650620ULCR00002                  130000.0         125931.40
# 3      25650621ULMB00001                   70000.0          60867.83
# 4      25650621ULMB00011                    3000.0           1585.66
# ...                  ...                       ...               ...
# 53491  25651231ULMB00013                   40000.0          37993.41
# 53492  25651231REUC00010                  140000.0         140000.00
# 53493  25651231REUM00003                   61800.0          61800.00
# 53494  25651230REUC00088                  180000.0         180000.00
# 53495  25651231REUC00011                  123000.0         123000.00
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 0                                12      M 1992-12-05          พนักงานบริษัท
# 1                                12      M 1986-08-15                  อื่นๆ
# 2                                60      F 1996-04-30                  อื่นๆ
# 3                                36      M 1979-04-01                  อื่นๆ
# 4                                13      M 1967-05-04          STREET VENDOR
# ...                             ...    ...        ...                    ...
# 53491                            24      M 1977-02-25                เกษตรกร
# 53492                            60      M 1965-06-30                เกษตรกร
# 53493                            36      F 1983-11-21          STREET VENDOR
# 53494                            60      M 1974-07-28     พนักงานรัฐวิสาหกิจ
# 53495                            60      M 1990-10-15                  อื่นๆ
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 0                         10000.00                   PU        TOYOTA  ...
# 1                         25000.09                   MC         HONDA  ...
# 2                         15000.00                  CAR         HONDA  ...
# 3                         20000.00                   MC        YAMAHA  ...
# 4                         30000.00                   MC         HONDA  ...
# ...                            ...                  ...           ...  ...
# 53491                     60000.00                   MC         HONDA  ...
# 53492                     24500.00                   PU         ISUZU  ...
# 53493                     45000.00                   MC         HONDA  ...
# 53494                     32000.00                   PU         MAZDA  ...
# 53495                     60000.00                  CAR         HONDA  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 0                     2002                 EP            225500
# 1                     2018                 BV             64500
# 2                     2005                 DK            220500
# 3                     2021                 CE             81500
# 4                     2010                 AY             20000
# ...                    ...                ...               ...
# 53491                 2022                 CP             53000
# 53492                 2006                 CU            176000
# 53493                 2021                 BQ             82500
# 53494                 2012                 AL            280000
# 53495                 2005                 BJ            164000
#
#        System CAR Code (Daily) System CAR Code Date  \
# 0                           S1           2022-12-26
# 1                           S1           2022-06-20
# 2                           S1           2022-06-20
# 3                           S1           2022-06-21
# 4                           S1           2022-06-21
# ...                        ...                  ...
# 53491                       S1           2022-12-31
# 53492                       S1           2022-12-31
# 53493                       S1           2022-12-31
# 53494                       S1           2022-12-31
# 53495                       S1           2022-12-31
#
#       Final CAR Code Previous Month DPD     Application Status age  \
# 0                                S1   4  APPLICATION_COMPLETED  31
# 1                                S1   0  APPLICATION_COMPLETED  37
# 2                                S1   0  APPLICATION_COMPLETED  27
# 3                                S1   0  APPLICATION_COMPLETED  44
# 4                                S1   0  APPLICATION_COMPLETED  56
# ...                             ...  ..                    ...  ..
# 53491                            S1   0  APPLICATION_COMPLETED  46
# 53492                            S1   0  APPLICATION_COMPLETED  58
# 53493                            S1   0  APPLICATION_COMPLETED  40
# 53494                            S1   0  APPLICATION_COMPLETED  49
# 53495                            S1   0  APPLICATION_COMPLETED  33
#
#        Vehicle Age
# 0               21
# 1                5
# 2               18
# 3                2
# 4               13
# ...            ...
# 53491            1
# 53492           17
# 53493            2
# 53494           11
# 53495           18
#
# [53496 rows x 21 columns]

# %%
df[df['Application Number'].duplicated()]
# Out:
#       Application Number  Principal Approve Amount  Principal Amount  \
# 178    25650627REUM00012                   18000.0           4246.18
# 188    25650627REUM00017                   50000.0           8475.68
# 295    25650629ULCR00015                   60000.0          59928.81
# 369    25650629ULMB00149                   34000.0          -2253.34
# 446    25650629ULMB00319                    5000.0           2586.19
# ...                  ...                       ...               ...
# 21708  25651004ULMB00196                   26000.0          26000.00
# 22663  25651006REUC00190                  250000.0         250000.00
# 24290  25651011ULCR00132                  143000.0         143000.00
# 26203  25651019ULMB00004                   34000.0          34000.00
# 32590  25651105ULCR00078                   60000.0          58627.75
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 178                              24      M 1997-09-07          STREET VENDOR
# 188                              36      M 1995-11-09                  อื่นๆ
# 295                              36      M 1986-11-15                  อื่นๆ
# 369                              12      F 2001-08-11                  อื่นๆ
# 446                              12      F 1992-07-08          พนักงานบริษัท
# ...                             ...    ...        ...                    ...
# 21708                            36      M 1974-06-05                  อื่นๆ
# 22663                            60      F 1979-03-04                  อื่นๆ
# 24290                            60      M 1976-10-10          พนักงานบริษัท
# 26203                            36      M 1983-08-12                  อื่นๆ
# 32590                            60      M 1964-08-11                อาจารย์
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 178                        18000.0                   MC         HONDA  ...
# 188                         1500.0                   MC         HONDA  ...
# 295                        80000.0                  CAR         ISUZU  ...
# 369                        20000.0                   MC         HONDA  ...
# 446                        12000.0                   MC         HONDA  ...
# ...                            ...                  ...           ...  ...
# 21708                      15000.0                   MC         HONDA  ...
# 22663                      40000.0                   PU        TOYOTA  ...
# 24290                      13000.0                   PU        NISSAN  ...
# 26203                      20000.0                   MC        YAMAHA  ...
# 32590                      60000.0                   PU        TOYOTA  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 178                   2009                 AI             24000
# 188                   2019                 CF             72000
# 295                   2000                 FR            358000
# 369                   2021                 BX             45500
# 446                   2021                 BZ             43500
# ...                    ...                ...               ...
# 21708                 2013                 CC             35500
# 22663                 2005                 AY            331000
# 24290                 2007                 BR            204000
# 26203                 2020                 CN             56500
# 32590                 2005                 CM            301500
#
#        System CAR Code (Daily) System CAR Code Date  \
# 178                         S1           2022-12-08
# 188                         S1           2022-12-28
# 295                         S2           2023-01-03
# 369                         S1           2022-09-21
# 446                         S1           2022-06-29
# ...                        ...                  ...
# 21708                       S2           2023-01-03
# 22663                       S1           2022-10-07
# 24290                       S1           2022-10-12
# 26203                       S1           2022-10-19
# 32590                       S1           2022-11-05
#
#       Final CAR Code Previous Month DPD     Application Status age  \
# 178                              S3   0  APPLICATION_COMPLETED  26
# 188                              S3   0  APPLICATION_COMPLETED  28
# 295                              S1  28  APPLICATION_COMPLETED  37
# 369                              S2   0  APPLICATION_COMPLETED  22
# 446                              S1   0  APPLICATION_COMPLETED  31
# ...                             ...  ..                    ...  ..
# 21708                            S1  28  APPLICATION_COMPLETED  49
# 22663                            S1   0  APPLICATION_COMPLETED  44
# 24290                            S1   0  APPLICATION_COMPLETED  47
# 26203                            S1   7  APPLICATION_COMPLETED  40
# 32590                            S1   0  APPLICATION_COMPLETED  59
#
#        Vehicle Age
# 178             14
# 188              4
# 295             23
# 369              2
# 446              2
# ...            ...
# 21708           10
# 22663           18
# 24290           16
# 26203            3
# 32590           18
#
# [73 rows x 21 columns]

# %%
df.drop_duplicates(['Application Number'], inplace=True)

df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53423 entries, 0 to 53422
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Application Number             53423 non-null  object
#  1   Principal Approve Amount       53423 non-null  float64
#  2   Principal Amount               53423 non-null  float64
#  3   Repayment Tenor Month Number   53423 non-null  int64
#  4   Gender                         53423 non-null  object
#  5   DOB                            53423 non-null  datetime64[ns]
#  6   Occupation Description         53423 non-null  object
#  7   Total Income Amount (Month)    53423 non-null  float64
#  8   Collateral Type Code           53423 non-null  object
#  9   Vehicle Brand                  53423 non-null  object
#  10  Vehicle Model                  53423 non-null  object
#  11  Vehicle Release Year           53423 non-null  int64
#  12  Vehicle Sub Model              53423 non-null  object
#  13  Evaluation Amount              53423 non-null  int64
#  14  System CAR Code (Daily)        53423 non-null  object
#  15  System CAR Code Date           53423 non-null  datetime64[ns]
#  16  Final CAR Code Previous Month  53423 non-null  object
#  17  DPD                            53423 non-null  int64
#  18  Application Status             53423 non-null  object
#  19  age                            53423 non-null  int64
#  20  Vehicle Age                    53423 non-null  int64
# dtypes: datetime64[ns](2), float64(3), int64(6), object(10)
# memory usage: 8.6+ MB

# %%
df.isna().sum()
# Out:
# Application Number               0
# Principal Approve Amount         0
# Principal Amount                 0
# Repayment Tenor Month Number     0
# Gender                           0
# DOB                              0
# Occupation Description           0
# Total Income Amount (Month)      0
# Collateral Type Code             0
# Vehicle Brand                    0
# Vehicle Model                    0
# Vehicle Release Year             0
# Vehicle Sub Model                0
# Evaluation Amount                0
# System CAR Code (Daily)          0
# System CAR Code Date             0
# Final CAR Code Previous Month    0
# DPD                              0
# Application Status               0
# age                              0
# Vehicle Age                      0
# dtype: int64

# %%
df['Repayment Tenor Month Number']=df['Repayment Tenor Month Number'].astype(int)
df['Vehicle Release Year']=df['Vehicle Release Year'].astype(int)
df['DPD']=df['DPD'].astype(np.int64)
df['Vehicle Release Year']=df['Vehicle Release Year'].astype(np.int64)
df['Vehicle Age']=df['Vehicle Age'].astype(np.int64)

# %%
print(df.shape)
df.tail()
# Out:
# (53423, 21)
#       Application Number  Principal Approve Amount  Principal Amount  \
# 53418  25651231ULMB00013                   40000.0          37993.41
# 53419  25651231REUC00010                  140000.0         140000.00
# 53420  25651231REUM00003                   61800.0          61800.00
# 53421  25651230REUC00088                  180000.0         180000.00
# 53422  25651231REUC00011                  123000.0         123000.00
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 53418                            24      M 1977-02-25                เกษตรกร
# 53419                            60      M 1965-06-30                เกษตรกร
# 53420                            36      F 1983-11-21          STREET VENDOR
# 53421                            60      M 1974-07-28     พนักงานรัฐวิสาหกิจ
# 53422                            60      M 1990-10-15                  อื่นๆ
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 53418                      60000.0                   MC         HONDA  ...
# 53419                      24500.0                   PU         ISUZU  ...
# 53420                      45000.0                   MC         HONDA  ...
# 53421                      32000.0                   PU         MAZDA  ...
# 53422                      60000.0                  CAR         HONDA  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 53418                 2022                 CP             53000
# 53419                 2006                 CU            176000
# 53420                 2021                 BQ             82500
# 53421                 2012                 AL            280000
# 53422                 2005                 BJ            164000
#
#        System CAR Code (Daily) System CAR Code Date  \
# 53418                       S1           2022-12-31
# 53419                       S1           2022-12-31
# 53420                       S1           2022-12-31
# 53421                       S1           2022-12-31
# 53422                       S1           2022-12-31
#
#       Final CAR Code Previous Month DPD     Application Status age  \
# 53418                            S1   0  APPLICATION_COMPLETED  46
# 53419                            S1   0  APPLICATION_COMPLETED  58
# 53420                            S1   0  APPLICATION_COMPLETED  40
# 53421                            S1   0  APPLICATION_COMPLETED  49
# 53422                            S1   0  APPLICATION_COMPLETED  33
#
#        Vehicle Age
# 53418            1
# 53419           17
# 53420            2
# 53421           11
# 53422           18
#
# [5 rows x 21 columns]

# %% [markdown]
# ##หาค่าที่เป็น NPL

# %%
df.head()
# Out:
#   Application Number  Principal Approve Amount  Principal Amount  \
# 0  25651226INSI00001                    7500.0              0.00
# 1  25650620ULMB00004                   20000.0          13492.22
# 2  25650620ULCR00002                  130000.0         125931.40
# 3  25650621ULMB00001                   70000.0          60867.83
# 4  25650621ULMB00011                    3000.0           1585.66
#
#    Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 0                            12      M 1992-12-05          พนักงานบริษัท
# 1                            12      M 1986-08-15                  อื่นๆ
# 2                            60      F 1996-04-30                  อื่นๆ
# 3                            36      M 1979-04-01                  อื่นๆ
# 4                            13      M 1967-05-04          STREET VENDOR
#
#    Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 0                     10000.00                   PU        TOYOTA  ...
# 1                     25000.09                   MC         HONDA  ...
# 2                     15000.00                  CAR         HONDA  ...
# 3                     20000.00                   MC        YAMAHA  ...
# 4                     30000.00                   MC         HONDA  ...
#
#   Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 0                 2002                 EP            225500
# 1                 2018                 BV             64500
# 2                 2005                 DK            220500
# 3                 2021                 CE             81500
# 4                 2010                 AY             20000
#
#    System CAR Code (Daily) System CAR Code Date Final CAR Code Previous Month  \
# 0                       S1           2022-12-26                            S1
# 1                       S1           2022-06-20                            S1
# 2                       S1           2022-06-20                            S1
# 3                       S1           2022-06-21                            S1
# 4                       S1           2022-06-21                            S1
#
#   DPD     Application Status age  Vehicle Age
# 0   4  APPLICATION_COMPLETED  31           21
# 1   0  APPLICATION_COMPLETED  37            5
# 2   0  APPLICATION_COMPLETED  27           18
# 3   0  APPLICATION_COMPLETED  44            2
# 4   0  APPLICATION_COMPLETED  56           13
#
# [5 rows x 21 columns]

# %%
df['Collateral Type Code'].value_counts()
# Out:
# MC       25938
# PU       14475
# CAR      12311
# VAN        388
# TRUCK      311
# Name: Collateral Type Code, dtype: int64

# %%
df0 = df[df['DPD']==0]
df0.shape
# Out:
# (51355, 21)

# %%
indexApp = df[ (df['DPD'] == 0)].index
df.drop(indexApp , inplace=True)

# %%
df1_30 = df[(df['DPD'] >= 1) & (df['DPD'] <= 30)]
df1_30.shape
# Out:
# (1469, 21)

# %%
df31_60 = df[(df['DPD'] >= 30) & (df['DPD'] <= 60)]
df31_60.shape
# Out:
# (442, 21)

# %%
df61_90 = df[(df['DPD'] >= 60) & (df['DPD'] <= 90)]
df61_90.shape
# Out:
# (100, 21)

# %%
df90up = df[df['DPD']>=90]
df90up.shape
# Out:
# (57, 21)

# %%
print("DPD 0",df0.shape)
print("df1_30",df1_30.shape)
print("df31_60",df31_60.shape)
print("df61_90",df61_90.shape)
print("df90up",df90up.shape)
# Out:
# DPD 0 (51355, 21)
# df1_30 (1469, 21)
# df31_60 (442, 21)
# df61_90 (100, 21)
# df90up (57, 21)

# %%
df['DPD'].value_counts()
# Out:
# 25     368
# 2      267
# 55     177
# 22     165
# 7      136
# 28     133
# 13     112
# 4      104
# 17      70
# 58      64
# 19      62
# 10      52
# 52      52
# 47      42
# 32      29
# 89      22
# 43      22
# 37      20
# 40      19
# 63      15
# 93      15
# 78      13
# 83      13
# 49      11
# 116     10
# 74      10
# 86       9
# 108      7
# 65       6
# 34       6
# 98       5
# 68       5
# 113      4
# 104      4
# 71       4
# 95       4
# 110      3
# 80       3
# 119      2
# 132      1
# 124      1
# 147      1
# Name: DPD, dtype: int64

# %%
df['Collateral Type Code'].value_counts()
# Out:
# MC       1246
# PU        434
# CAR       370
# VAN        12
# TRUCK       6
# Name: Collateral Type Code, dtype: int64

# %% [markdown]
# #อาจจะต้องแบ่งแบบตัว 0 วันมารวมใน PL ด้วย
# 0 วัน
# 1-30 วัน
# 31-60

# %%
from pandas.api.types import CategoricalDtype
#bins = [0,30,60]
pl_npl = ['PL','NPL']
df['DPD'] = pd.cut(df.DPD,
                                    bins = [1,30,90],
                                    labels=pl_npl, 
                                    right=True).astype(CategoricalDtype(pl_npl, ordered=True))
df.sort_values(by='DPD')
# Out:
#       Application Number  Principal Approve Amount  Principal Amount  \
# 0      25651226INSI00001                    7500.0              0.00
# 16766  25650919REUC00052                  249000.0         249000.00
# 16757  25650919REUM00030                   28000.0          27902.58
# 16717  25650919REUM00020                   18000.0          17569.10
# 16708  25650919ULCR00045                  220000.0         219526.10
# ...                  ...                       ...               ...
# 4689   25650730ULCR00055                  230000.0         230000.00
# 5826   25650804ULCR00031                  144000.0         144000.00
# 8543   25650817ULMB00101                   35000.0          33839.69
# 9020   25650819ULMB00039                   39000.0          39000.00
# 9753   25650822ULCR00153                  300000.0         300000.00
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 0                                12      M 1992-12-05          พนักงานบริษัท
# 16766                            60      M 1995-06-30          พนักงานบริษัท
# 16757                            36      F 1988-03-23          STREET VENDOR
# 16717                            36      F 1982-06-17          พนักงานบริษัท
# 16708                            54      F 1988-03-13     บุคลากรทางการแพทย์
# ...                             ...    ...        ...                    ...
# 4689                             60      F 1989-06-29          STREET VENDOR
# 5826                             60      M 1969-12-11              ข้าราชการ
# 8543                             24      F 1988-02-18          STREET VENDOR
# 9020                             36      F 1988-01-09          พนักงานบริษัท
# 9753                             60      F 1971-11-04                เกษตรกร
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 0                          10000.0                   PU        TOYOTA  ...
# 16766                      20000.0                   PU    MITSUBISHI  ...
# 16757                      40000.0                   MC         HONDA  ...
# 16717                      10000.0                   MC        YAMAHA  ...
# 16708                      32000.0                  CAR        TOYOTA  ...
# ...                            ...                  ...           ...  ...
# 4689                       50000.0                  CAR        TOYOTA  ...
# 5826                       36000.0                  CAR        TOYOTA  ...
# 8543                       70000.0                   MC        YAMAHA  ...
# 9020                       15000.0                   MC         HONDA  ...
# 9753                       20000.0                   PU        NISSAN  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 0                     2002                 EP            225500
# 16766                 2015                 BJ            354000
# 16757                 2018                 BP             37500
# 16717                 2012                 AE             25000
# 16708                 2014                 BA            295500
# ...                    ...                ...               ...
# 4689                  2011                 AO            308000
# 5826                  2010                 DX            222000
# 8543                  2017                 CQ             46500
# 9020                  2017                 CO             53000
# 9753                  2019                 DQ            484500
#
#        System CAR Code (Daily) System CAR Code Date  \
# 0                           S1           2022-12-26
# 16766                       S1           2022-09-19
# 16757                       S1           2022-09-19
# 16717                       S1           2022-09-19
# 16708                       S2           2023-01-06
# ...                        ...                  ...
# 4689                        S3           2022-12-29
# 5826                        S3           2022-12-29
# 8543                        S2           2023-01-13
# 9020                        S3           2022-12-29
# 9753                        S3           2022-12-29
#
#       Final CAR Code Previous Month  DPD     Application Status age  \
# 0                                S1   PL  APPLICATION_COMPLETED  31
# 16766                            S1   PL  APPLICATION_COMPLETED  28
# 16757                            S1   PL  APPLICATION_COMPLETED  35
# 16717                            S1   PL  APPLICATION_COMPLETED  41
# 16708                            S1   PL  APPLICATION_COMPLETED  35
# ...                             ...  ...                    ...  ..
# 4689                             S2  NaN  APPLICATION_COMPLETED  34
# 5826                             S2  NaN  APPLICATION_COMPLETED  54
# 8543                             S3  NaN  APPLICATION_COMPLETED  35
# 9020                             S2  NaN  APPLICATION_COMPLETED  35
# 9753                             S2  NaN  APPLICATION_COMPLETED  52
#
#        Vehicle Age
# 0               21
# 16766            8
# 16757            5
# 16717           11
# 16708            9
# ...            ...
# 4689            12
# 5826            13
# 8543             6
# 9020             6
# 9753             4
#
# [2068 rows x 21 columns]

# %%
df[(df['DPD'] == 'PL')]
# Out:
#       Application Number  Principal Approve Amount  Principal Amount  \
# 0      25651226INSI00001                   7500.00              0.00
# 10     25650621ULCR00004                  30000.00          26618.83
# 65     25650623ULCR00008                 220000.00              0.00
# 72     25650623ULMB00025                  30000.00          29959.48
# 94     25650624ULCR00024                  90000.00          89933.60
# ...                  ...                       ...               ...
# 43069  25651128TRUM00004                  31632.28          31632.28
# 43073  25651130TDUM00035                  22853.47          22853.47
# 43583  25651130TDUC00041                 190000.00         186373.32
# 47433  25651124TDUC00006                  97000.00          97000.00
# 50786  25651118TDUC00007                 180000.00              0.00
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 0                                12      M 1992-12-05          พนักงานบริษัท
# 10                               24      M 1994-12-24                  อื่นๆ
# 65                               60      M 1972-05-05          พนักงานบริษัท
# 72                               24      F 1979-05-30                  อื่นๆ
# 94                               24      M 1966-09-20          พนักงานบริษัท
# ...                             ...    ...        ...                    ...
# 43069                            48      F 1973-06-24                  อื่นๆ
# 43073                            36      F 1989-07-18          พนักงานบริษัท
# 43583                            84      M 1985-01-15          พนักงานบริษัท
# 47433                            36      F 1982-11-30          STREET VENDOR
# 50786                            36      M 1966-01-15              ข้าราชการ
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 0                          10000.0                   PU        TOYOTA  ...
# 10                         40000.0                  CAR     CHEVROLET  ...
# 65                         25000.0                   PU        TOYOTA  ...
# 72                         20000.0                   MC        YAMAHA  ...
# 94                         15000.0                   PU    MITSUBISHI  ...
# ...                            ...                  ...           ...  ...
# 43069                      10000.0                   MC         HONDA  ...
# 43073                      10000.0                   MC           GPX  ...
# 43583                      60000.0                  CAR         HONDA  ...
# 47433                      70000.0                   PU        NISSAN  ...
# 50786                      48000.0                  CAR        TOYOTA  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 0                     2002                 EP            225500
# 10                    2012                 BT            121000
# 65                    2006                 CY            296000
# 72                    2019                 AY             46500
# 94                    2012                 AO            157000
# ...                    ...                ...               ...
# 43069                 2019                 DS             43000
# 43073                 2019                 AC             33500
# 43583                 2008                 AN            252500
# 47433                 2005                 BB            161500
# 50786                 2012                 GN            280000
#
#        System CAR Code (Daily) System CAR Code Date  \
# 0                           S1           2022-12-26
# 10                          S1           2022-06-21
# 65                          S1           2023-01-11
# 72                          S2           2023-01-14
# 94                          S2           2023-01-09
# ...                        ...                  ...
# 43069                       S2           2022-11-28
# 43073                       S2           2022-11-30
# 43583                       S2           2022-11-30
# 47433                       S2           2022-11-24
# 50786                       S1           2023-01-07
#
#       Final CAR Code Previous Month DPD     Application Status age  \
# 0                                S1  PL  APPLICATION_COMPLETED  31
# 10                               S1  PL  APPLICATION_COMPLETED  29
# 65                               S2  PL  APPLICATION_COMPLETED  51
# 72                               S1  PL  APPLICATION_COMPLETED  44
# 94                               S1  PL  APPLICATION_COMPLETED  57
# ...                             ...  ..                    ...  ..
# 43069                            S2  PL  APPLICATION_COMPLETED  50
# 43073                            S2  PL  APPLICATION_COMPLETED  34
# 43583                            S2  PL  APPLICATION_COMPLETED  38
# 47433                            S2  PL  APPLICATION_COMPLETED  41
# 50786                            S2  PL  APPLICATION_COMPLETED  57
#
#        Vehicle Age
# 0               21
# 10              11
# 65              17
# 72               4
# 94              11
# ...            ...
# 43069            4
# 43073            4
# 43583           15
# 47433           18
# 50786           11
#
# [1469 rows x 21 columns]

# %%
df[(df['DPD'] == 'NPL')]
# Out:
#       Application Number  Principal Approve Amount  Principal Amount  \
# 22     25650621ULMB00060                   20000.0          18434.00
# 59     25650623REUC00004                  165000.0              0.00
# 61     25650623ULMB00007                   28000.0          26483.19
# 69     25650623ULMB00021                   14000.0          13975.46
# 111    25650625REUC00004                  130000.0         130000.00
# ...                  ...                       ...               ...
# 27564  25651022REUM00023                   16000.0          16000.00
# 27854  25651024ULMB00245                   14000.0          14000.00
# 27996  25651025ULMB00010                   34000.0          34000.00
# 28168  25651025REUM00059                   40000.0          40000.00
# 33214  25651031TDUM00029                   27900.0          25804.97
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 22                               12      M 1994-01-26                  อื่นๆ
# 59                               60      M 1990-10-19          STREET VENDOR
# 61                               24      F 1989-12-30                  อื่นๆ
# 69                               36      F 1982-10-22          พนักงานบริษัท
# 111                              60      F 1986-12-09          STREET VENDOR
# ...                             ...    ...        ...                    ...
# 27564                            36      F 1957-11-26                เกษตรกร
# 27854                            12      F 1982-03-22                  อื่นๆ
# 27996                            36      M 1990-01-09          STREET VENDOR
# 28168                            24      F 1976-08-22          STREET VENDOR
# 33214                            24      F 1989-05-13          STREET VENDOR
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 22                         15000.0                   MC         HONDA  ...
# 59                         30000.0                  CAR        TOYOTA  ...
# 61                         15000.0                   MC         HONDA  ...
# 69                         13000.0                   MC         HONDA  ...
# 111                        35000.0                   PU          FORD  ...
# ...                            ...                  ...           ...  ...
# 27564                      13000.0                   MC         HONDA  ...
# 27854                       8000.0                   MC         HONDA  ...
# 27996                      15000.0                   MC         HONDA  ...
# 28168                      25000.0                   MC         HONDA  ...
# 33214                      12000.0                   MC         HONDA  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 22                    2019                 DB             34500
# 59                    2010                 DZ            240000
# 61                    2015                 CC             44000
# 69                    2009                 AF             19000
# 111                   2007                 BU            212000
# ...                    ...                ...               ...
# 27564                 2011                 AZ             22000
# 27854                 2010                 AG             20000
# 27996                 2022                 CP             53000
# 28168                 2022                 CP             57100
# 33214                 2015                 CI             37000
#
#        System CAR Code (Daily) System CAR Code Date  \
# 22                          S2           2023-01-10
# 59                          S1           2023-01-10
# 61                          S2           2022-11-27
# 69                          S2           2022-12-07
# 111                         S2           2022-12-07
# ...                        ...                  ...
# 27564                       S2           2022-12-22
# 27854                       S2           2022-12-25
# 27996                       S2           2022-12-30
# 28168                       S2           2022-12-25
# 33214                       S2           2022-10-31
#
#       Final CAR Code Previous Month  DPD     Application Status age  \
# 22                               S3  NPL  APPLICATION_COMPLETED  29
# 59                               S2  NPL  APPLICATION_COMPLETED  33
# 61                               S1  NPL  APPLICATION_COMPLETED  34
# 69                               S1  NPL  APPLICATION_COMPLETED  41
# 111                              S1  NPL  APPLICATION_COMPLETED  37
# ...                             ...  ...                    ...  ..
# 27564                            S1  NPL  APPLICATION_COMPLETED  66
# 27854                            S1  NPL  APPLICATION_COMPLETED  41
# 27996                            S1  NPL  APPLICATION_COMPLETED  33
# 28168                            S1  NPL  APPLICATION_COMPLETED  47
# 33214                            S2  NPL  APPLICATION_COMPLETED  34
#
#        Vehicle Age
# 22               4
# 59              13
# 61               8
# 69              14
# 111             16
# ...            ...
# 27564           12
# 27854           13
# 27996            1
# 28168            1
# 33214            8
#
# [542 rows x 21 columns]

# %%
df.DPD.unique()
# Out:
# ['PL', 'NPL', NaN]
# Categories (2, object): ['PL' < 'NPL']

# %%
'''bins = [0,30,60]
pl_npl = ['PL','NPL']

dpd_cate = pd.cut(df.DPD, bins, labels=pl_npl)
dpd_cate'''
# Out:
# "bins = [0,30,60]\npl_npl = ['PL','NPL']\n\ndpd_cate = pd.cut(df.DPD, bins, labels=pl_npl)\ndpd_cate"

# %%
df['DPD'].value_counts()
# Out:
# PL     1469
# NPL     542
# Name: DPD, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2068 entries, 0 to 50786
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Application Number             2068 non-null   object
#  1   Principal Approve Amount       2068 non-null   float64
#  2   Principal Amount               2068 non-null   float64
#  3   Repayment Tenor Month Number   2068 non-null   int32
#  4   Gender                         2068 non-null   object
#  5   DOB                            2068 non-null   datetime64[ns]
#  6   Occupation Description         2068 non-null   object
#  7   Total Income Amount (Month)    2068 non-null   float64
#  8   Collateral Type Code           2068 non-null   object
#  9   Vehicle Brand                  2068 non-null   object
#  10  Vehicle Model                  2068 non-null   object
#  11  Vehicle Release Year           2068 non-null   int64
#  12  Vehicle Sub Model              2068 non-null   object
#  13  Evaluation Amount              2068 non-null   int64
#  14  System CAR Code (Daily)        2068 non-null   object
#  15  System CAR Code Date           2068 non-null   datetime64[ns]
#  16  Final CAR Code Previous Month  2068 non-null   object
#  17  DPD                            2011 non-null   category
#  18  Application Status             2068 non-null   object
#  19  age                            2068 non-null   int64
#  20  Vehicle Age                    2068 non-null   int64
# dtypes: category(1), datetime64[ns](2), float64(3), int32(1), int64(4), object(10)
# memory usage: 333.3+ KB

# %%
df[(df['System CAR Code (Daily)']=='S1')]
# Out:
#       Application Number  Principal Approve Amount  Principal Amount  \
# 0      25651226INSI00001                    7500.0              0.00
# 10     25650621ULCR00004                   30000.0          26618.83
# 59     25650623REUC00004                  165000.0              0.00
# 65     25650623ULCR00008                  220000.0              0.00
# 148    25650627ULMB00032                   17000.0          16920.59
# ...                  ...                       ...               ...
# 39673  25651126ULMB00072                   25000.0          24319.58
# 39923  25651128ULMB00077                   24000.0          24000.00
# 39991  25651128ULMB00120                   24000.0          23969.51
# 40692  25651129REUM00109                   12800.0          12448.22
# 50786  25651118TDUC00007                  180000.0              0.00
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 0                                12      M 1992-12-05          พนักงานบริษัท
# 10                               24      M 1994-12-24                  อื่นๆ
# 59                               60      M 1990-10-19          STREET VENDOR
# 65                               60      M 1972-05-05          พนักงานบริษัท
# 148                              36      M 1988-01-02                  อื่นๆ
# ...                             ...    ...        ...                    ...
# 39673                            36      M 1983-02-08          พนักงานบริษัท
# 39923                            30      F 1994-07-30          STREET VENDOR
# 39991                            18      F 1992-11-19          พนักงานบริษัท
# 40692                            36      F 1988-11-30          พนักงานบริษัท
# 50786                            36      M 1966-01-15              ข้าราชการ
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 0                          10000.0                   PU        TOYOTA  ...
# 10                         40000.0                  CAR     CHEVROLET  ...
# 59                         30000.0                  CAR        TOYOTA  ...
# 65                         25000.0                   PU        TOYOTA  ...
# 148                        20000.0                   MC      KAWASAKI  ...
# ...                            ...                  ...           ...  ...
# 39673                      10000.0                   MC         HONDA  ...
# 39923                      30000.0                   MC         HONDA  ...
# 39991                      15000.0                   MC        YAMAHA  ...
# 40692                      18000.0                   MC         HONDA  ...
# 50786                      48000.0                  CAR        TOYOTA  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 0                     2002                 EP            225500
# 10                    2012                 BT            121000
# 59                    2010                 DZ            240000
# 65                    2006                 CY            296000
# 148                   2014                 AL             24500
# ...                    ...                ...               ...
# 39673                 2015                 CM             38000
# 39923                 2016                 CP             32000
# 39991                 2015                 BF             33000
# 40692                 2010                 AE             17000
# 50786                 2012                 GN            280000
#
#        System CAR Code (Daily) System CAR Code Date  \
# 0                           S1           2022-12-26
# 10                          S1           2022-06-21
# 59                          S1           2023-01-10
# 65                          S1           2023-01-11
# 148                         S1           2022-06-27
# ...                        ...                  ...
# 39673                       S1           2022-11-27
# 39923                       S1           2022-11-28
# 39991                       S1           2022-11-28
# 40692                       S1           2022-11-29
# 50786                       S1           2023-01-07
#
#       Final CAR Code Previous Month  DPD     Application Status age  \
# 0                                S1   PL  APPLICATION_COMPLETED  31
# 10                               S1   PL  APPLICATION_COMPLETED  29
# 59                               S2  NPL  APPLICATION_COMPLETED  33
# 65                               S2   PL  APPLICATION_COMPLETED  51
# 148                              S1   PL  APPLICATION_COMPLETED  35
# ...                             ...  ...                    ...  ..
# 39673                            S1   PL  APPLICATION_COMPLETED  40
# 39923                            S1   PL  APPLICATION_COMPLETED  29
# 39991                            S1   PL  APPLICATION_COMPLETED  31
# 40692                            S1   PL  APPLICATION_COMPLETED  35
# 50786                            S2   PL  APPLICATION_COMPLETED  57
#
#        Vehicle Age
# 0               21
# 10              11
# 59              13
# 65              17
# 148              9
# ...            ...
# 39673            8
# 39923            7
# 39991            8
# 40692           13
# 50786           11
#
# [962 rows x 21 columns]

# %%
df[(df['System CAR Code (Daily)']=='S2')]
# Out:
#       Application Number  Principal Approve Amount  Principal Amount  \
# 22     25650621ULMB00060                  20000.00          18434.00
# 61     25650623ULMB00007                  28000.00          26483.19
# 69     25650623ULMB00021                  14000.00          13975.46
# 72     25650623ULMB00025                  30000.00          29959.48
# 94     25650624ULCR00024                  90000.00          89933.60
# ...                  ...                       ...               ...
# 42439  25651205TRUC00002                 189000.00         189000.00
# 43069  25651128TRUM00004                  31632.28          31632.28
# 43073  25651130TDUM00035                  22853.47          22853.47
# 43583  25651130TDUC00041                 190000.00         186373.32
# 47433  25651124TDUC00006                  97000.00          97000.00
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 22                               12      M 1994-01-26                  อื่นๆ
# 61                               24      F 1989-12-30                  อื่นๆ
# 69                               36      F 1982-10-22          พนักงานบริษัท
# 72                               24      F 1979-05-30                  อื่นๆ
# 94                               24      M 1966-09-20          พนักงานบริษัท
# ...                             ...    ...        ...                    ...
# 42439                            72      F 1977-09-05          พนักงานบริษัท
# 43069                            48      F 1973-06-24                  อื่นๆ
# 43073                            36      F 1989-07-18          พนักงานบริษัท
# 43583                            84      M 1985-01-15          พนักงานบริษัท
# 47433                            36      F 1982-11-30          STREET VENDOR
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 22                         15000.0                   MC         HONDA  ...
# 61                         15000.0                   MC         HONDA  ...
# 69                         13000.0                   MC         HONDA  ...
# 72                         20000.0                   MC        YAMAHA  ...
# 94                         15000.0                   PU    MITSUBISHI  ...
# ...                            ...                  ...           ...  ...
# 42439                      20620.0                  CAR        TOYOTA  ...
# 43069                      10000.0                   MC         HONDA  ...
# 43073                      10000.0                   MC           GPX  ...
# 43583                      60000.0                  CAR         HONDA  ...
# 47433                      70000.0                   PU        NISSAN  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 22                    2019                 DB             34500
# 61                    2015                 CC             44000
# 69                    2009                 AF             19000
# 72                    2019                 AY             46500
# 94                    2012                 AO            157000
# ...                    ...                ...               ...
# 42439                 2013                 DV            253500
# 43069                 2019                 DS             43000
# 43073                 2019                 AC             33500
# 43583                 2008                 AN            252500
# 47433                 2005                 BB            161500
#
#        System CAR Code (Daily) System CAR Code Date  \
# 22                          S2           2023-01-10
# 61                          S2           2022-11-27
# 69                          S2           2022-12-07
# 72                          S2           2023-01-14
# 94                          S2           2023-01-09
# ...                        ...                  ...
# 42439                       S2           2022-12-06
# 43069                       S2           2022-11-28
# 43073                       S2           2022-11-30
# 43583                       S2           2022-11-30
# 47433                       S2           2022-11-24
#
#       Final CAR Code Previous Month  DPD     Application Status age  \
# 22                               S3  NPL  APPLICATION_COMPLETED  29
# 61                               S1  NPL  APPLICATION_COMPLETED  34
# 69                               S1  NPL  APPLICATION_COMPLETED  41
# 72                               S1   PL  APPLICATION_COMPLETED  44
# 94                               S1   PL  APPLICATION_COMPLETED  57
# ...                             ...  ...                    ...  ..
# 42439                            S2   PL  APPLICATION_COMPLETED  46
# 43069                            S2   PL  APPLICATION_COMPLETED  50
# 43073                            S2   PL  APPLICATION_COMPLETED  34
# 43583                            S2   PL  APPLICATION_COMPLETED  38
# 47433                            S2   PL  APPLICATION_COMPLETED  41
#
#        Vehicle Age
# 22               4
# 61               8
# 69              14
# 72               4
# 94              11
# ...            ...
# 42439           10
# 43069            4
# 43073            4
# 43583           15
# 47433           18
#
# [998 rows x 21 columns]

# %%
df[(df['System CAR Code (Daily)']=='S3')]
# Out:
#       Application Number  Principal Approve Amount  Principal Amount  \
# 64     25650623REUM00003                   51000.0          50715.88
# 131    25650627ULMB00018                   37000.0          36011.72
# 426    25650629ULMB00287                   35000.0          35000.00
# 503    25650630ULCR00044                  190000.0         190000.00
# 505    25650630REUM00024                   15000.0          15000.00
# ...                  ...                       ...               ...
# 8266   25650816REUC00035                  350000.0         350000.00
# 8898   25650818REUC00106                  218000.0         218000.00
# 9020   25650819ULMB00039                   39000.0          39000.00
# 9753   25650822ULCR00153                  300000.0         300000.00
# 10406  25650825ULMB00051                   30000.0          29711.00
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 64                               36      F 1995-04-10                  อื่นๆ
# 131                              36      M 1997-02-03          พนักงานบริษัท
# 426                              36      F 1981-06-13          STREET VENDOR
# 503                              60      M 1988-08-03                  อื่นๆ
# 505                              18      F 1984-10-30          STREET VENDOR
# ...                             ...    ...        ...                    ...
# 8266                             60      F 1966-04-05          STREET VENDOR
# 8898                             48      M 1987-12-14              ข้าราชการ
# 9020                             36      F 1988-01-09          พนักงานบริษัท
# 9753                             60      F 1971-11-04                เกษตรกร
# 10406                            24      M 1985-12-22          STREET VENDOR
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 64                         10000.0                   MC         HONDA  ...
# 131                        20500.0                   MC         HONDA  ...
# 426                        15000.0                   MC         HONDA  ...
# 503                        30000.0                  CAR        TOYOTA  ...
# 505                        15000.0                   MC         HONDA  ...
# ...                            ...                  ...           ...  ...
# 8266                       20000.0                   PU         ISUZU  ...
# 8898                       24050.0                  CAR        TOYOTA  ...
# 9020                       15000.0                   MC         HONDA  ...
# 9753                       20000.0                   PU        NISSAN  ...
# 10406                      15000.0                   MC         HONDA  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 64                    2018                 BV             64500
# 131                   2022                 CP             57100
# 426                   2020                 CX             46500
# 503                   2009                 EO            323500
# 505                   2012                 BO             23000
# ...                    ...                ...               ...
# 8266                  2016                 CC            438500
# 8898                  2013                 DU            290000
# 9020                  2017                 CO             53000
# 9753                  2019                 DQ            484500
# 10406                 2013                 BW             35000
#
#        System CAR Code (Daily) System CAR Code Date  \
# 64                          S3           2022-12-29
# 131                         S3           2022-12-29
# 426                         S3           2022-12-06
# 503                         S3           2022-11-28
# 505                         S3           2022-12-09
# ...                        ...                  ...
# 8266                        S3           2023-01-13
# 8898                        S3           2023-01-13
# 9020                        S3           2022-12-29
# 9753                        S3           2022-12-29
# 10406                       S3           2023-01-13
#
#       Final CAR Code Previous Month  DPD     Application Status age  \
# 64                               S2  NaN  APPLICATION_COMPLETED  28
# 131                              S2  NaN  APPLICATION_COMPLETED  26
# 426                              S2  NaN  APPLICATION_COMPLETED  42
# 503                              S2  NaN  APPLICATION_COMPLETED  35
# 505                              S2  NaN  APPLICATION_COMPLETED  39
# ...                             ...  ...                    ...  ..
# 8266                             S2  NPL  APPLICATION_COMPLETED  57
# 8898                             S2  NPL  APPLICATION_COMPLETED  36
# 9020                             S2  NaN  APPLICATION_COMPLETED  35
# 9753                             S2  NaN  APPLICATION_COMPLETED  52
# 10406                            S2  NPL  APPLICATION_COMPLETED  38
#
#        Vehicle Age
# 64               5
# 131              1
# 426              3
# 503             14
# 505             11
# ...            ...
# 8266             7
# 8898            10
# 9020             6
# 9753             4
# 10406           10
#
# [108 rows x 21 columns]

# %% [markdown]
# ##Data Selection

# %% [markdown]
# ###นำข้อมูลผู้ประกอบการออกเนื่องจาก รายได้ที่กรอกมามี 100000 - 700000 จึงทำให้เกิด outliner:

# %%
df['Occupation Description'].unique()
# Out:
# array(['พนักงานบริษัท', 'อื่นๆ', 'STREET VENDOR', 'พนักงานรัฐวิสาหกิจ',
#        'เกษตรกร', 'ข้าราชการ', 'อาจารย์', 'เลี้ยงสัตว์',
#        'บุคลากรทางการแพทย์', 'นักกฎหมาย', 'สถาปนิก'], dtype=object)

# %%
indexApp = df[(df['Vehicle Age']>=30)].index
df.drop(indexApp , inplace=True)
df
# Out:
#       Application Number  Principal Approve Amount  Principal Amount  \
# 0      25651226INSI00001                   7500.00              0.00
# 10     25650621ULCR00004                  30000.00          26618.83
# 22     25650621ULMB00060                  20000.00          18434.00
# 59     25650623REUC00004                 165000.00              0.00
# 61     25650623ULMB00007                  28000.00          26483.19
# ...                  ...                       ...               ...
# 43069  25651128TRUM00004                  31632.28          31632.28
# 43073  25651130TDUM00035                  22853.47          22853.47
# 43583  25651130TDUC00041                 190000.00         186373.32
# 47433  25651124TDUC00006                  97000.00          97000.00
# 50786  25651118TDUC00007                 180000.00              0.00
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 0                                12      M 1992-12-05          พนักงานบริษัท
# 10                               24      M 1994-12-24                  อื่นๆ
# 22                               12      M 1994-01-26                  อื่นๆ
# 59                               60      M 1990-10-19          STREET VENDOR
# 61                               24      F 1989-12-30                  อื่นๆ
# ...                             ...    ...        ...                    ...
# 43069                            48      F 1973-06-24                  อื่นๆ
# 43073                            36      F 1989-07-18          พนักงานบริษัท
# 43583                            84      M 1985-01-15          พนักงานบริษัท
# 47433                            36      F 1982-11-30          STREET VENDOR
# 50786                            36      M 1966-01-15              ข้าราชการ
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 0                          10000.0                   PU        TOYOTA  ...
# 10                         40000.0                  CAR     CHEVROLET  ...
# 22                         15000.0                   MC         HONDA  ...
# 59                         30000.0                  CAR        TOYOTA  ...
# 61                         15000.0                   MC         HONDA  ...
# ...                            ...                  ...           ...  ...
# 43069                      10000.0                   MC         HONDA  ...
# 43073                      10000.0                   MC           GPX  ...
# 43583                      60000.0                  CAR         HONDA  ...
# 47433                      70000.0                   PU        NISSAN  ...
# 50786                      48000.0                  CAR        TOYOTA  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 0                     2002                 EP            225500
# 10                    2012                 BT            121000
# 22                    2019                 DB             34500
# 59                    2010                 DZ            240000
# 61                    2015                 CC             44000
# ...                    ...                ...               ...
# 43069                 2019                 DS             43000
# 43073                 2019                 AC             33500
# 43583                 2008                 AN            252500
# 47433                 2005                 BB            161500
# 50786                 2012                 GN            280000
#
#        System CAR Code (Daily) System CAR Code Date  \
# 0                           S1           2022-12-26
# 10                          S1           2022-06-21
# 22                          S2           2023-01-10
# 59                          S1           2023-01-10
# 61                          S2           2022-11-27
# ...                        ...                  ...
# 43069                       S2           2022-11-28
# 43073                       S2           2022-11-30
# 43583                       S2           2022-11-30
# 47433                       S2           2022-11-24
# 50786                       S1           2023-01-07
#
#       Final CAR Code Previous Month  DPD     Application Status age  \
# 0                                S1   PL  APPLICATION_COMPLETED  31
# 10                               S1   PL  APPLICATION_COMPLETED  29
# 22                               S3  NPL  APPLICATION_COMPLETED  29
# 59                               S2  NPL  APPLICATION_COMPLETED  33
# 61                               S1  NPL  APPLICATION_COMPLETED  34
# ...                             ...  ...                    ...  ..
# 43069                            S2   PL  APPLICATION_COMPLETED  50
# 43073                            S2   PL  APPLICATION_COMPLETED  34
# 43583                            S2   PL  APPLICATION_COMPLETED  38
# 47433                            S2   PL  APPLICATION_COMPLETED  41
# 50786                            S2   PL  APPLICATION_COMPLETED  57
#
#        Vehicle Age
# 0               21
# 10              11
# 22               4
# 59              13
# 61               8
# ...            ...
# 43069            4
# 43073            4
# 43583           15
# 47433           18
# 50786           11
#
# [2068 rows x 21 columns]

# %%
df.describe().round(2)
# Out:
#        Principal Approve Amount  Principal Amount  \
# count                   2068.00           2068.00
# mean                   91370.39          86373.81
# std                   106936.25         104496.47
# min                     3000.00              0.00
# 25%                    23000.00          20000.00
# 50%                    30000.00          28988.38
# 75%                   150000.00         148139.07
# max                  1000000.00        1000000.00
#
#        Repayment Tenor Month Number  Total Income Amount (Month)  \
# count                       2068.00                      2068.00
# mean                          40.55                     22798.16
# std                           22.18                     20248.42
# min                           12.00                         0.00
# 25%                           24.00                     14500.00
# 50%                           36.00                     19000.00
# 75%                           60.00                     25000.00
# max                          120.00                    500000.00
#
#        Vehicle Release Year  Evaluation Amount      age  Vehicle Age
# count               2068.00            2068.00  2068.00      2068.00
# mean                2012.69          135716.25    40.15        10.31
# std                    5.07          153828.10    10.13         5.07
# min                 1994.00           10000.00    21.00         1.00
# 25%                 2010.00           35000.00    32.00         6.00
# 50%                 2013.00           44000.00    39.00        10.00
# 75%                 2017.00          226625.00    47.00        13.00
# max                 2022.00         1470000.00    72.00        29.00

# %%
indexApp = df[ (df['Total Income Amount (Month)'] <= 5000)].index
df.drop(indexApp , inplace=True)

# %%
'''indexApp = df[ (df['Total Income Amount (Month)'] >= 100000)].index
df.drop(indexApp , inplace=True)'''
# Out:
# "indexApp = df[ (df['Total Income Amount (Month)'] >= 100000)].index\ndf.drop(indexApp , inplace=True)"

# %%
'''indexApp = df[ (df['Total Income Amount (Month)'] <= 6000)].index
df.drop(indexApp , inplace=True)'''
# Out:
# "indexApp = df[ (df['Total Income Amount (Month)'] <= 6000)].index\ndf.drop(indexApp , inplace=True)"

# %% [markdown]
# ###Cleaning ข้อมูลจำนวนเดือนที่จะผ่อน

# %%
df['Repayment Tenor Month Number'].value_counts()
# Out:
# 36     560
# 60     473
# 24     352
# 12     173
# 18     165
# 48      86
# 30      60
# 120     55
# 72      34
# 84      21
# 61      19
# 42      17
# 96      11
# 54      10
# 49       6
# 108      5
# 37       2
# 28       1
# 38       1
# 25       1
# Name: Repayment Tenor Month Number, dtype: int64

# %%
df[ (df['Repayment Tenor Month Number'] < 6)]
# Out:
# Empty DataFrame
# Columns: [Application Number, Principal Approve Amount, Principal Amount, Repayment Tenor Month Number, Gender, DOB, Occupation Description, Total Income Amount (Month), Collateral Type Code, Vehicle Brand, Vehicle Model, Vehicle Release Year, Vehicle Sub Model, Evaluation Amount, System CAR Code (Daily), System CAR Code Date, Final CAR Code Previous Month, DPD, Application Status, age, Vehicle Age]
# Index: []
#
# [0 rows x 21 columns]

# %%
df[ (df['Repayment Tenor Month Number'] > 60)]
# Out:
#       Application Number  Principal Approve Amount  Principal Amount  \
# 1171   25650706REUC00052                  120000.0         120000.00
# 2101   25650712REUC00074                  180000.0         179522.88
# 2397   25650714REUC00053                  190000.0         184315.27
# 2404   25650715ULCR00026                  120000.0         119806.76
# 3371   25650721REUC00051                  140000.0         139849.27
# ...                  ...                       ...               ...
# 40765  25651130TRUC00016                  400000.0         394953.96
# 40769  25651130TRUC00021                  220000.0         219480.71
# 41160  25651130TRUC00042                  150000.0         150000.00
# 42439  25651205TRUC00002                  189000.0         189000.00
# 43583  25651130TDUC00041                  190000.0         186373.32
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 1171                             61      F 1989-07-18          STREET VENDOR
# 2101                             61      M 1986-01-03                เกษตรกร
# 2397                             61      F 1970-11-09          STREET VENDOR
# 2404                             61      F 1987-01-09          พนักงานบริษัท
# 3371                             61      F 1976-05-19          STREET VENDOR
# ...                             ...    ...        ...                    ...
# 40765                            72      M 1966-10-24                เกษตรกร
# 40769                           120      F 1980-02-04          พนักงานบริษัท
# 41160                            84      F 1970-01-12                เกษตรกร
# 42439                            72      F 1977-09-05          พนักงานบริษัท
# 43583                            84      M 1985-01-15          พนักงานบริษัท
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 1171                       20000.0                  CAR         HONDA  ...
# 2101                       15000.0                   PU         ISUZU  ...
# 2397                      100000.0                   PU        TOYOTA  ...
# 2404                       12000.0                  CAR         HONDA  ...
# 3371                       30000.0                  CAR         HONDA  ...
# ...                            ...                  ...           ...  ...
# 40765                      37000.0                   PU        TOYOTA  ...
# 40769                      26000.0                   PU         ISUZU  ...
# 41160                      15000.0                   PU        TOYOTA  ...
# 42439                      20620.0                  CAR        TOYOTA  ...
# 43583                      60000.0                  CAR         HONDA  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 1171                  2005                 CH            177000
# 2101                  2012                 BQ            431500
# 2397                  2007                 CS            246000
# 2404                  2004                 AT            164500
# 3371                  2006                 AE            218500
# ...                    ...                ...               ...
# 40765                 2013                 FS            708500
# 40769                 2007                 CV            286000
# 41160                 2003                 CF            219500
# 42439                 2013                 DV            253500
# 43583                 2008                 AN            252500
#
#        System CAR Code (Daily) System CAR Code Date  \
# 1171                        S1           2022-07-06
# 2101                        S1           2023-01-12
# 2397                        S1           2022-07-14
# 2404                        S1           2022-07-16
# 3371                        S1           2023-01-14
# ...                        ...                  ...
# 40765                       S2           2022-11-30
# 40769                       S2           2022-11-30
# 41160                       S2           2022-11-30
# 42439                       S2           2022-12-06
# 43583                       S2           2022-11-30
#
#       Final CAR Code Previous Month DPD     Application Status age  \
# 1171                             S1  PL  APPLICATION_COMPLETED  34
# 2101                             S2  PL  APPLICATION_COMPLETED  37
# 2397                             S1  PL  APPLICATION_COMPLETED  53
# 2404                             S1  PL  APPLICATION_COMPLETED  36
# 3371                             S2  PL  APPLICATION_COMPLETED  47
# ...                             ...  ..                    ...  ..
# 40765                            S2  PL  APPLICATION_COMPLETED  57
# 40769                            S2  PL  APPLICATION_COMPLETED  43
# 41160                            S2  PL  APPLICATION_COMPLETED  53
# 42439                            S2  PL  APPLICATION_COMPLETED  46
# 43583                            S2  PL  APPLICATION_COMPLETED  38
#
#        Vehicle Age
# 1171            18
# 2101            11
# 2397            16
# 2404            19
# 3371            17
# ...            ...
# 40765           10
# 40769           16
# 41160           20
# 42439           10
# 43583           15
#
# [145 rows x 21 columns]

# %%
indexApp = df[ (df['Repayment Tenor Month Number'] < 6)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] > 60)].index
df.drop(indexApp , inplace=True)
df.head(15)
# Out:
#     Application Number  Principal Approve Amount  Principal Amount  \
# 0    25651226INSI00001                    7500.0              0.00
# 10   25650621ULCR00004                   30000.0          26618.83
# 22   25650621ULMB00060                   20000.0          18434.00
# 59   25650623REUC00004                  165000.0              0.00
# 61   25650623ULMB00007                   28000.0          26483.19
# 64   25650623REUM00003                   51000.0          50715.88
# 65   25650623ULCR00008                  220000.0              0.00
# 69   25650623ULMB00021                   14000.0          13975.46
# 72   25650623ULMB00025                   30000.0          29959.48
# 94   25650624ULCR00024                   90000.0          89933.60
# 111  25650625REUC00004                  130000.0         130000.00
# 131  25650627ULMB00018                   37000.0          36011.72
# 145  25650627ULCR00018                  170000.0         166153.35
# 148  25650627ULMB00032                   17000.0          16920.59
# 161  25650627ULCR00027                  300000.0         298055.87
#
#      Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 0                              12      M 1992-12-05          พนักงานบริษัท
# 10                             24      M 1994-12-24                  อื่นๆ
# 22                             12      M 1994-01-26                  อื่นๆ
# 59                             60      M 1990-10-19          STREET VENDOR
# 61                             24      F 1989-12-30                  อื่นๆ
# 64                             36      F 1995-04-10                  อื่นๆ
# 65                             60      M 1972-05-05          พนักงานบริษัท
# 69                             36      F 1982-10-22          พนักงานบริษัท
# 72                             24      F 1979-05-30                  อื่นๆ
# 94                             24      M 1966-09-20          พนักงานบริษัท
# 111                            60      F 1986-12-09          STREET VENDOR
# 131                            36      M 1997-02-03          พนักงานบริษัท
# 145                            24      M 1962-01-30                  อื่นๆ
# 148                            36      M 1988-01-02                  อื่นๆ
# 161                            60      M 1984-09-10                  อื่นๆ
#
#      Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 0                        10000.0                   PU        TOYOTA  ...
# 10                       40000.0                  CAR     CHEVROLET  ...
# 22                       15000.0                   MC         HONDA  ...
# 59                       30000.0                  CAR        TOYOTA  ...
# 61                       15000.0                   MC         HONDA  ...
# 64                       10000.0                   MC         HONDA  ...
# 65                       25000.0                   PU        TOYOTA  ...
# 69                       13000.0                   MC         HONDA  ...
# 72                       20000.0                   MC        YAMAHA  ...
# 94                       15000.0                   PU    MITSUBISHI  ...
# 111                      35000.0                   PU          FORD  ...
# 131                      20500.0                   MC         HONDA  ...
# 145                      50000.0                  CAR        TOYOTA  ...
# 148                      20000.0                   MC      KAWASAKI  ...
# 161                      14000.0                   PU         ISUZU  ...
#
#     Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 0                   2002                 EP            225500
# 10                  2012                 BT            121000
# 22                  2019                 DB             34500
# 59                  2010                 DZ            240000
# 61                  2015                 CC             44000
# 64                  2018                 BV             64500
# 65                  2006                 CY            296000
# 69                  2009                 AF             19000
# 72                  2019                 AY             46500
# 94                  2012                 AO            157000
# 111                 2007                 BU            212000
# 131                 2022                 CP             57100
# 145                 2011                 AC            236500
# 148                 2014                 AL             24500
# 161                 2013                 CE            475500
#
#      System CAR Code (Daily) System CAR Code Date  \
# 0                         S1           2022-12-26
# 10                        S1           2022-06-21
# 22                        S2           2023-01-10
# 59                        S1           2023-01-10
# 61                        S2           2022-11-27
# 64                        S3           2022-12-29
# 65                        S1           2023-01-11
# 69                        S2           2022-12-07
# 72                        S2           2023-01-14
# 94                        S2           2023-01-09
# 111                       S2           2022-12-07
# 131                       S3           2022-12-29
# 145                       S2           2023-01-06
# 148                       S1           2022-06-27
# 161                       S2           2023-01-09
#
#     Final CAR Code Previous Month  DPD     Application Status age  Vehicle Age
# 0                              S1   PL  APPLICATION_COMPLETED  31           21
# 10                             S1   PL  APPLICATION_COMPLETED  29           11
# 22                             S3  NPL  APPLICATION_COMPLETED  29            4
# 59                             S2  NPL  APPLICATION_COMPLETED  33           13
# 61                             S1  NPL  APPLICATION_COMPLETED  34            8
# 64                             S2  NaN  APPLICATION_COMPLETED  28            5
# 65                             S2   PL  APPLICATION_COMPLETED  51           17
# 69                             S1  NPL  APPLICATION_COMPLETED  41           14
# 72                             S1   PL  APPLICATION_COMPLETED  44            4
# 94                             S1   PL  APPLICATION_COMPLETED  57           11
# 111                            S1  NPL  APPLICATION_COMPLETED  37           16
# 131                            S2  NaN  APPLICATION_COMPLETED  26            1
# 145                            S1   PL  APPLICATION_COMPLETED  61           12
# 148                            S1   PL  APPLICATION_COMPLETED  35            9
# 161                            S1  NPL  APPLICATION_COMPLETED  39           10
#
# [15 rows x 21 columns]

# %%
df['Repayment Tenor Month Number'].value_counts()
# Out:
# 36    560
# 60    473
# 24    352
# 12    173
# 18    165
# 48     86
# 30     60
# 42     17
# 54     10
# 49      6
# 37      2
# 25      1
# 28      1
# 38      1
# Name: Repayment Tenor Month Number, dtype: int64

# %%
indexApp = df[ (df['Repayment Tenor Month Number'] == 54)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 37)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 25)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 49)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 13)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 19)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 31)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 15)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 32)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 28)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 14)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 26)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 38)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 55)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 56)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 17)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 20)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 35)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 40)].index
df.drop(indexApp , inplace=True)
indexApp = df[ (df['Repayment Tenor Month Number'] == 50)].index
df.drop(indexApp , inplace=True)
df.head(15)
# Out:
#     Application Number  Principal Approve Amount  Principal Amount  \
# 0    25651226INSI00001                    7500.0              0.00
# 10   25650621ULCR00004                   30000.0          26618.83
# 22   25650621ULMB00060                   20000.0          18434.00
# 59   25650623REUC00004                  165000.0              0.00
# 61   25650623ULMB00007                   28000.0          26483.19
# 64   25650623REUM00003                   51000.0          50715.88
# 65   25650623ULCR00008                  220000.0              0.00
# 69   25650623ULMB00021                   14000.0          13975.46
# 72   25650623ULMB00025                   30000.0          29959.48
# 94   25650624ULCR00024                   90000.0          89933.60
# 111  25650625REUC00004                  130000.0         130000.00
# 131  25650627ULMB00018                   37000.0          36011.72
# 145  25650627ULCR00018                  170000.0         166153.35
# 148  25650627ULMB00032                   17000.0          16920.59
# 161  25650627ULCR00027                  300000.0         298055.87
#
#      Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 0                              12      M 1992-12-05          พนักงานบริษัท
# 10                             24      M 1994-12-24                  อื่นๆ
# 22                             12      M 1994-01-26                  อื่นๆ
# 59                             60      M 1990-10-19          STREET VENDOR
# 61                             24      F 1989-12-30                  อื่นๆ
# 64                             36      F 1995-04-10                  อื่นๆ
# 65                             60      M 1972-05-05          พนักงานบริษัท
# 69                             36      F 1982-10-22          พนักงานบริษัท
# 72                             24      F 1979-05-30                  อื่นๆ
# 94                             24      M 1966-09-20          พนักงานบริษัท
# 111                            60      F 1986-12-09          STREET VENDOR
# 131                            36      M 1997-02-03          พนักงานบริษัท
# 145                            24      M 1962-01-30                  อื่นๆ
# 148                            36      M 1988-01-02                  อื่นๆ
# 161                            60      M 1984-09-10                  อื่นๆ
#
#      Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 0                        10000.0                   PU        TOYOTA  ...
# 10                       40000.0                  CAR     CHEVROLET  ...
# 22                       15000.0                   MC         HONDA  ...
# 59                       30000.0                  CAR        TOYOTA  ...
# 61                       15000.0                   MC         HONDA  ...
# 64                       10000.0                   MC         HONDA  ...
# 65                       25000.0                   PU        TOYOTA  ...
# 69                       13000.0                   MC         HONDA  ...
# 72                       20000.0                   MC        YAMAHA  ...
# 94                       15000.0                   PU    MITSUBISHI  ...
# 111                      35000.0                   PU          FORD  ...
# 131                      20500.0                   MC         HONDA  ...
# 145                      50000.0                  CAR        TOYOTA  ...
# 148                      20000.0                   MC      KAWASAKI  ...
# 161                      14000.0                   PU         ISUZU  ...
#
#     Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 0                   2002                 EP            225500
# 10                  2012                 BT            121000
# 22                  2019                 DB             34500
# 59                  2010                 DZ            240000
# 61                  2015                 CC             44000
# 64                  2018                 BV             64500
# 65                  2006                 CY            296000
# 69                  2009                 AF             19000
# 72                  2019                 AY             46500
# 94                  2012                 AO            157000
# 111                 2007                 BU            212000
# 131                 2022                 CP             57100
# 145                 2011                 AC            236500
# 148                 2014                 AL             24500
# 161                 2013                 CE            475500
#
#      System CAR Code (Daily) System CAR Code Date  \
# 0                         S1           2022-12-26
# 10                        S1           2022-06-21
# 22                        S2           2023-01-10
# 59                        S1           2023-01-10
# 61                        S2           2022-11-27
# 64                        S3           2022-12-29
# 65                        S1           2023-01-11
# 69                        S2           2022-12-07
# 72                        S2           2023-01-14
# 94                        S2           2023-01-09
# 111                       S2           2022-12-07
# 131                       S3           2022-12-29
# 145                       S2           2023-01-06
# 148                       S1           2022-06-27
# 161                       S2           2023-01-09
#
#     Final CAR Code Previous Month  DPD     Application Status age  Vehicle Age
# 0                              S1   PL  APPLICATION_COMPLETED  31           21
# 10                             S1   PL  APPLICATION_COMPLETED  29           11
# 22                             S3  NPL  APPLICATION_COMPLETED  29            4
# 59                             S2  NPL  APPLICATION_COMPLETED  33           13
# 61                             S1  NPL  APPLICATION_COMPLETED  34            8
# 64                             S2  NaN  APPLICATION_COMPLETED  28            5
# 65                             S2   PL  APPLICATION_COMPLETED  51           17
# 69                             S1  NPL  APPLICATION_COMPLETED  41           14
# 72                             S1   PL  APPLICATION_COMPLETED  44            4
# 94                             S1   PL  APPLICATION_COMPLETED  57           11
# 111                            S1  NPL  APPLICATION_COMPLETED  37           16
# 131                            S2  NaN  APPLICATION_COMPLETED  26            1
# 145                            S1   PL  APPLICATION_COMPLETED  61           12
# 148                            S1   PL  APPLICATION_COMPLETED  35            9
# 161                            S1  NPL  APPLICATION_COMPLETED  39           10
#
# [15 rows x 21 columns]

# %%
df['Repayment Tenor Month Number'].value_counts()
# Out:
# 36    560
# 60    473
# 24    352
# 12    173
# 18    165
# 48     86
# 30     60
# 42     17
# Name: Repayment Tenor Month Number, dtype: int64

# %% [markdown]
# ###ข้อมูลที่เหลือหลังจากถูกการ Cleaning

# %%
df.shape
# Out:
# (1886, 21)

# %%
df[(df['DPD']=='PL')]
# Out:
#       Application Number  Principal Approve Amount  Principal Amount  \
# 0      25651226INSI00001                   7500.00              0.00
# 10     25650621ULCR00004                  30000.00          26618.83
# 65     25650623ULCR00008                 220000.00              0.00
# 72     25650623ULMB00025                  30000.00          29959.48
# 94     25650624ULCR00024                  90000.00          89933.60
# ...                  ...                       ...               ...
# 42273  25651126TDUC00001                 210000.00         210000.00
# 43069  25651128TRUM00004                  31632.28          31632.28
# 43073  25651130TDUM00035                  22853.47          22853.47
# 47433  25651124TDUC00006                  97000.00          97000.00
# 50786  25651118TDUC00007                 180000.00              0.00
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 0                                12      M 1992-12-05          พนักงานบริษัท
# 10                               24      M 1994-12-24                  อื่นๆ
# 65                               60      M 1972-05-05          พนักงานบริษัท
# 72                               24      F 1979-05-30                  อื่นๆ
# 94                               24      M 1966-09-20          พนักงานบริษัท
# ...                             ...    ...        ...                    ...
# 42273                            60      M 1968-09-26          STREET VENDOR
# 43069                            48      F 1973-06-24                  อื่นๆ
# 43073                            36      F 1989-07-18          พนักงานบริษัท
# 47433                            36      F 1982-11-30          STREET VENDOR
# 50786                            36      M 1966-01-15              ข้าราชการ
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 0                          10000.0                   PU        TOYOTA  ...
# 10                         40000.0                  CAR     CHEVROLET  ...
# 65                         25000.0                   PU        TOYOTA  ...
# 72                         20000.0                   MC        YAMAHA  ...
# 94                         15000.0                   PU    MITSUBISHI  ...
# ...                            ...                  ...           ...  ...
# 42273                      20000.0                  CAR         HONDA  ...
# 43069                      10000.0                   MC         HONDA  ...
# 43073                      10000.0                   MC           GPX  ...
# 47433                      70000.0                   PU        NISSAN  ...
# 50786                      48000.0                  CAR        TOYOTA  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 0                     2002                 EP            225500
# 10                    2012                 BT            121000
# 65                    2006                 CY            296000
# 72                    2019                 AY             46500
# 94                    2012                 AO            157000
# ...                    ...                ...               ...
# 42273                 2013                 AB            282500
# 43069                 2019                 DS             43000
# 43073                 2019                 AC             33500
# 47433                 2005                 BB            161500
# 50786                 2012                 GN            280000
#
#        System CAR Code (Daily) System CAR Code Date  \
# 0                           S1           2022-12-26
# 10                          S1           2022-06-21
# 65                          S1           2023-01-11
# 72                          S2           2023-01-14
# 94                          S2           2023-01-09
# ...                        ...                  ...
# 42273                       S2           2022-11-29
# 43069                       S2           2022-11-28
# 43073                       S2           2022-11-30
# 47433                       S2           2022-11-24
# 50786                       S1           2023-01-07
#
#       Final CAR Code Previous Month DPD     Application Status age  \
# 0                                S1  PL  APPLICATION_COMPLETED  31
# 10                               S1  PL  APPLICATION_COMPLETED  29
# 65                               S2  PL  APPLICATION_COMPLETED  51
# 72                               S1  PL  APPLICATION_COMPLETED  44
# 94                               S1  PL  APPLICATION_COMPLETED  57
# ...                             ...  ..                    ...  ..
# 42273                            S2  PL  APPLICATION_COMPLETED  55
# 43069                            S2  PL  APPLICATION_COMPLETED  50
# 43073                            S2  PL  APPLICATION_COMPLETED  34
# 47433                            S2  PL  APPLICATION_COMPLETED  41
# 50786                            S2  PL  APPLICATION_COMPLETED  57
#
#        Vehicle Age
# 0               21
# 10              11
# 65              17
# 72               4
# 94              11
# ...            ...
# 42273           10
# 43069            4
# 43073            4
# 47433           18
# 50786           11
#
# [1300 rows x 21 columns]

# %%
df[(df['DPD']=='NPL')]
# Out:
#       Application Number  Principal Approve Amount  Principal Amount  \
# 22     25650621ULMB00060                   20000.0          18434.00
# 59     25650623REUC00004                  165000.0              0.00
# 61     25650623ULMB00007                   28000.0          26483.19
# 69     25650623ULMB00021                   14000.0          13975.46
# 111    25650625REUC00004                  130000.0         130000.00
# ...                  ...                       ...               ...
# 27564  25651022REUM00023                   16000.0          16000.00
# 27854  25651024ULMB00245                   14000.0          14000.00
# 27996  25651025ULMB00010                   34000.0          34000.00
# 28168  25651025REUM00059                   40000.0          40000.00
# 33214  25651031TDUM00029                   27900.0          25804.97
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 22                               12      M 1994-01-26                  อื่นๆ
# 59                               60      M 1990-10-19          STREET VENDOR
# 61                               24      F 1989-12-30                  อื่นๆ
# 69                               36      F 1982-10-22          พนักงานบริษัท
# 111                              60      F 1986-12-09          STREET VENDOR
# ...                             ...    ...        ...                    ...
# 27564                            36      F 1957-11-26                เกษตรกร
# 27854                            12      F 1982-03-22                  อื่นๆ
# 27996                            36      M 1990-01-09          STREET VENDOR
# 28168                            24      F 1976-08-22          STREET VENDOR
# 33214                            24      F 1989-05-13          STREET VENDOR
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 22                         15000.0                   MC         HONDA  ...
# 59                         30000.0                  CAR        TOYOTA  ...
# 61                         15000.0                   MC         HONDA  ...
# 69                         13000.0                   MC         HONDA  ...
# 111                        35000.0                   PU          FORD  ...
# ...                            ...                  ...           ...  ...
# 27564                      13000.0                   MC         HONDA  ...
# 27854                       8000.0                   MC         HONDA  ...
# 27996                      15000.0                   MC         HONDA  ...
# 28168                      25000.0                   MC         HONDA  ...
# 33214                      12000.0                   MC         HONDA  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 22                    2019                 DB             34500
# 59                    2010                 DZ            240000
# 61                    2015                 CC             44000
# 69                    2009                 AF             19000
# 111                   2007                 BU            212000
# ...                    ...                ...               ...
# 27564                 2011                 AZ             22000
# 27854                 2010                 AG             20000
# 27996                 2022                 CP             53000
# 28168                 2022                 CP             57100
# 33214                 2015                 CI             37000
#
#        System CAR Code (Daily) System CAR Code Date  \
# 22                          S2           2023-01-10
# 59                          S1           2023-01-10
# 61                          S2           2022-11-27
# 69                          S2           2022-12-07
# 111                         S2           2022-12-07
# ...                        ...                  ...
# 27564                       S2           2022-12-22
# 27854                       S2           2022-12-25
# 27996                       S2           2022-12-30
# 28168                       S2           2022-12-25
# 33214                       S2           2022-10-31
#
#       Final CAR Code Previous Month  DPD     Application Status age  \
# 22                               S3  NPL  APPLICATION_COMPLETED  29
# 59                               S2  NPL  APPLICATION_COMPLETED  33
# 61                               S1  NPL  APPLICATION_COMPLETED  34
# 69                               S1  NPL  APPLICATION_COMPLETED  41
# 111                              S1  NPL  APPLICATION_COMPLETED  37
# ...                             ...  ...                    ...  ..
# 27564                            S1  NPL  APPLICATION_COMPLETED  66
# 27854                            S1  NPL  APPLICATION_COMPLETED  41
# 27996                            S1  NPL  APPLICATION_COMPLETED  33
# 28168                            S1  NPL  APPLICATION_COMPLETED  47
# 33214                            S2  NPL  APPLICATION_COMPLETED  34
#
#        Vehicle Age
# 22               4
# 59              13
# 61               8
# 69              14
# 111             16
# ...            ...
# 27564           12
# 27854           13
# 27996            1
# 28168            1
# 33214            8
#
# [529 rows x 21 columns]

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ##Data Transformation

# %% [markdown]
# ###ทำการแบ่งข้อมูล จาก 6403 rows แบ่งมา 4% ของข้อมูลทั้งหมดของ PL ก่อนเข้าสู่ Machine Learning

# %%
'''df_pl = df[df['DPD']=='PL'].sample(frac=0.04, replace=True, random_state=1)
df_pl.shape'''
# Out:
# "df_pl = df[df['DPD']=='PL'].sample(frac=0.04, replace=True, random_state=1)\ndf_pl.shape"

# %%
'''df_npl = df.loc[df['DPD']!='PL']
df_npl.shape'''
# Out:
# "df_npl = df.loc[df['DPD']!='PL']\ndf_npl.shape"

# %% [markdown]
# PL 256 rows
#
# NPL 76 rows
#
# total 332 rows
#
# คิด % NPL ได้เท่ากับ 22.891%

# %%
'''join_df = [df_pl,df_npl]
new_df = pd.concat(join_df, ignore_index=True)'''
# Out:
# 'join_df = [df_pl,df_npl]\nnew_df = pd.concat(join_df, ignore_index=True)'

# %%
#new_df['DPD'].describe()

# %%
#new_df['DPD'].value_counts()

# %%
df.describe().round(2)
# Out:
#        Principal Approve Amount  Principal Amount  \
# count                   1886.00           1886.00
# mean                   82447.85          77634.69
# std                   102894.66         100683.20
# min                     3000.00              0.00
# 25%                    21000.00          18956.57
# 50%                    29000.00          28000.00
# 75%                   130000.00         114285.55
# max                  1000000.00        1000000.00
#
#        Repayment Tenor Month Number  Total Income Amount (Month)  \
# count                       1886.00                      1886.00
# mean                          36.41                     22640.56
# std                           16.14                     20419.85
# min                           12.00                      5200.00
# 25%                           24.00                     14000.00
# 50%                           36.00                     18285.00
# 75%                           60.00                     25000.00
# max                           60.00                    500000.00
#
#        Vehicle Release Year  Evaluation Amount      age  Vehicle Age
# count               1886.00            1886.00  1886.00      1886.00
# mean                2012.83          124382.18    40.01        10.17
# std                    5.06          148931.72    10.13         5.06
# min                 1994.00           10000.00    21.00         1.00
# 25%                 2010.00           34000.00    32.00         6.00
# 50%                 2013.00           42000.00    39.00        10.00
# 75%                 2017.00          207375.00    46.00        13.00
# max                 2022.00         1470000.00    72.00        29.00

# %%
#new_df['Application Status'].value_counts()

# %%
#new_df[(new_df['Application Status']=='APPLICATION_COMPLETED')]

# %%
df[(df['Application Status']=='APPLICATION_COMPLETED')]
# Out:
#       Application Number  Principal Approve Amount  Principal Amount  \
# 0      25651226INSI00001                   7500.00              0.00
# 10     25650621ULCR00004                  30000.00          26618.83
# 22     25650621ULMB00060                  20000.00          18434.00
# 59     25650623REUC00004                 165000.00              0.00
# 61     25650623ULMB00007                  28000.00          26483.19
# ...                  ...                       ...               ...
# 42273  25651126TDUC00001                 210000.00         210000.00
# 43069  25651128TRUM00004                  31632.28          31632.28
# 43073  25651130TDUM00035                  22853.47          22853.47
# 47433  25651124TDUC00006                  97000.00          97000.00
# 50786  25651118TDUC00007                 180000.00              0.00
#
#        Repayment Tenor Month Number Gender        DOB Occupation Description  \
# 0                                12      M 1992-12-05          พนักงานบริษัท
# 10                               24      M 1994-12-24                  อื่นๆ
# 22                               12      M 1994-01-26                  อื่นๆ
# 59                               60      M 1990-10-19          STREET VENDOR
# 61                               24      F 1989-12-30                  อื่นๆ
# ...                             ...    ...        ...                    ...
# 42273                            60      M 1968-09-26          STREET VENDOR
# 43069                            48      F 1973-06-24                  อื่นๆ
# 43073                            36      F 1989-07-18          พนักงานบริษัท
# 47433                            36      F 1982-11-30          STREET VENDOR
# 50786                            36      M 1966-01-15              ข้าราชการ
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  ...  \
# 0                          10000.0                   PU        TOYOTA  ...
# 10                         40000.0                  CAR     CHEVROLET  ...
# 22                         15000.0                   MC         HONDA  ...
# 59                         30000.0                  CAR        TOYOTA  ...
# 61                         15000.0                   MC         HONDA  ...
# ...                            ...                  ...           ...  ...
# 42273                      20000.0                  CAR         HONDA  ...
# 43069                      10000.0                   MC         HONDA  ...
# 43073                      10000.0                   MC           GPX  ...
# 47433                      70000.0                   PU        NISSAN  ...
# 50786                      48000.0                  CAR        TOYOTA  ...
#
#       Vehicle Release Year  Vehicle Sub Model Evaluation Amount  \
# 0                     2002                 EP            225500
# 10                    2012                 BT            121000
# 22                    2019                 DB             34500
# 59                    2010                 DZ            240000
# 61                    2015                 CC             44000
# ...                    ...                ...               ...
# 42273                 2013                 AB            282500
# 43069                 2019                 DS             43000
# 43073                 2019                 AC             33500
# 47433                 2005                 BB            161500
# 50786                 2012                 GN            280000
#
#        System CAR Code (Daily) System CAR Code Date  \
# 0                           S1           2022-12-26
# 10                          S1           2022-06-21
# 22                          S2           2023-01-10
# 59                          S1           2023-01-10
# 61                          S2           2022-11-27
# ...                        ...                  ...
# 42273                       S2           2022-11-29
# 43069                       S2           2022-11-28
# 43073                       S2           2022-11-30
# 47433                       S2           2022-11-24
# 50786                       S1           2023-01-07
#
#       Final CAR Code Previous Month  DPD     Application Status age  \
# 0                                S1   PL  APPLICATION_COMPLETED  31
# 10                               S1   PL  APPLICATION_COMPLETED  29
# 22                               S3  NPL  APPLICATION_COMPLETED  29
# 59                               S2  NPL  APPLICATION_COMPLETED  33
# 61                               S1  NPL  APPLICATION_COMPLETED  34
# ...                             ...  ...                    ...  ..
# 42273                            S2   PL  APPLICATION_COMPLETED  55
# 43069                            S2   PL  APPLICATION_COMPLETED  50
# 43073                            S2   PL  APPLICATION_COMPLETED  34
# 47433                            S2   PL  APPLICATION_COMPLETED  41
# 50786                            S2   PL  APPLICATION_COMPLETED  57
#
#        Vehicle Age
# 0               21
# 10              11
# 22               4
# 59              13
# 61               8
# ...            ...
# 42273           10
# 43069            4
# 43073            4
# 47433           18
# 50786           11
#
# [1886 rows x 21 columns]

# %%
df['Application Status'].value_counts()
# Out:
# APPLICATION_COMPLETED    1886
# Name: Application Status, dtype: int64

# %%
df.to_csv('chaiyo_clean_is2.csv')

# %%
df.columns
# Out:
# Index(['Application Number', 'Principal Approve Amount', 'Principal Amount',
#        'Repayment Tenor Month Number', 'Gender', 'DOB',
#        'Occupation Description', 'Total Income Amount (Month)',
#        'Collateral Type Code', 'Vehicle Brand', 'Vehicle Model',
#        'Vehicle Release Year', 'Vehicle Sub Model', 'Evaluation Amount',
#        'System CAR Code (Daily)', 'System CAR Code Date',
#        'Final CAR Code Previous Month', 'DPD', 'Application Status', 'age',
#        'Vehicle Age'],
#       dtype='object')

# %%
category = ['Repayment Tenor Month Number','Gender','Occupation Description','Collateral Type Code','Vehicle Release Year','Vehicle Age','Total Income Amount (Month)','age','System CAR Code (Daily)','DPD','Application Status']

for i in category:
    print(f'{i}:{df[i].unique()}\n')
# Out:
# Repayment Tenor Month Number:[12 24 60 36 18 48 30 42]
#
# Gender:['M' 'F']
#
# Occupation Description:['พนักงานบริษัท' 'อื่นๆ' 'STREET VENDOR' 'พนักงานรัฐวิสาหกิจ' 'เกษตรกร'
#  'ข้าราชการ' 'อาจารย์' 'เลี้ยงสัตว์' 'บุคลากรทางการแพทย์' 'นักกฎหมาย'
#  'สถาปนิก']
#
# Collateral Type Code:['PU' 'CAR' 'MC' 'VAN' 'TRUCK']
#
# Vehicle Release Year:[2002 2012 2019 2010 2015 2018 2006 2009 2007 2022 2011 2014 2013 2008
#  2016 2000 2020 2005 2017 2003 2021 1999 2004 1996 1997 2001 1994 1995]
#
# Vehicle Age:[21 11  4 13  8  5 17 14 16  1 12  9 10 15  7 23  3 18  6 20  2 24 19 27
#  26 22 29 28]
#
# Total Income Amount (Month):[ 10000.    40000.    15000.    30000.    25000.    13000.    20000.
#   35000.    20500.    50000.    14000.    19950.    12000.     9233.
#   24000.     6500.    80000.    19500.    60000.    28000.    23538.
#   19000.     7000.    70000.    18200.     9000.    11000.    38000.
#   30000.01  92693.    18370.    17000.    47500.    45000.    22000.
#   22770.    16600.    23000.    16000.    22230.    90000.    24500.
#   69040.     6000.    36000.    27000.    17485.    18000.    11200.
#   32000.    33000.    33780.    16737.   200000.    17166.6   27880.
#   11500.     8500.    21000.    26000.    40590.    78000.    12500.
#   64072.    21500.    60120.    19430.    53000.    75000.    15500.
#  150000.    28500.    55980.   247739.    16290.    49000.    36070.
#   27006.    29300.    32930.    24090.     9570.    54076.    27200.
#    9500.     9600.    18500.    31095.    13280.    26690.    21870.
#   24682.    14500.    63273.    44000.    30660.    82770.    20800.
#   22300.     9900.    37520.   108943.   500000.    97000.    13050.
#   51000.    14250.    16300.    15920.    43662.    10100.    17880.
#   24830.    27610.    43000.    63500.    24050.    14400.    16172.
#   23800.    35961.    21463.44  44500.     9000.06  39000.     5200.
#   35060.    37000.    55000.    24730.    36260.    10750.    13285.
#   13500.    16500.     8000.     7800.    29000.     7500.    43275.
#   32680.    13100.    15000.09 100000.    66000.    15400.    11850.
#    8800.    24700.    67000.    17800.    17500.    60500.    17300.
#   11296.    16100.    16430.    28600.    65000.     8600.    48000.
#   10350.    13852.    21900.     8400.    13000.09  20200.     7300.
#   12600.    97322.    13700.    21020.     9700.    18634.   170000.
#   11400.    17700.    19400.    41660.    32380.    29360.    23300.
#    9060.     9400.    56888.  ]
#
# age:[31 29 33 34 28 51 41 44 57 37 26 61 35 39 38 30 32 50 67 47 55 49 62 66
#  40 42 43 45 23 36 56 69 48 53 22 58 27 54 24 25 46 65 63 59 60 52 68 71
#  72 64 21 70]
#
# System CAR Code (Daily):['S1' 'S2' 'S3']
#
# DPD:['PL', 'NPL', NaN]
# Categories (2, object): ['PL' < 'NPL']
#
# Application Status:['APPLICATION_COMPLETED']

# %%
for i in category:
    print(f'{i}:{df[i].value_counts()}\n')
# Out:
# Repayment Tenor Month Number:36    560
# 60    473
# 24    352
# 12    173
# 18    165
# 48     86
# 30     60
# 42     17
# Name: Repayment Tenor Month Number, dtype: int64
#
# Gender:F    1057
# M     829
# Name: Gender, dtype: int64
#
# Occupation Description:STREET VENDOR         576
# อื่นๆ                 510
# พนักงานบริษัท         454
# เกษตรกร               213
# ข้าราชการ              55
# อาจารย์                32
# พนักงานรัฐวิสาหกิจ     29
# เลี้ยงสัตว์             7
# บุคลากรทางการแพทย์      7
# สถาปนิก                 2
# นักกฎหมาย               1
# Name: Occupation Description, dtype: int64
#
# Collateral Type Code:MC       1213
# PU        347
# CAR       308
# VAN        12
# TRUCK       6
# Name: Collateral Type Code, dtype: int64
#
# Vehicle Release Year:2012    198
# 2013    153
# 2017    149
# 2019    146
# 2018    146
# 2016    141
# 2010    126
# 2011    114
# 2014    102
# 2015     85
# 2008     75
# 2007     65
# 2005     64
# 2009     56
# 2020     56
# 2006     46
# 2004     34
# 2003     33
# 2021     23
# 2022     21
# 2002     15
# 2001      9
# 2000      9
# 1996      6
# 1999      5
# 1997      4
# 1994      4
# 1995      1
# Name: Vehicle Release Year, dtype: int64
#
# Vehicle Age:11    198
# 10    153
# 6     149
# 4     146
# 5     146
# 7     141
# 13    126
# 12    114
# 9     102
# 8      85
# 15     75
# 16     65
# 18     64
# 3      56
# 14     56
# 17     46
# 19     34
# 20     33
# 2      23
# 1      21
# 21     15
# 22      9
# 23      9
# 27      6
# 24      5
# 26      4
# 29      4
# 28      1
# Name: Vehicle Age, dtype: int64
#
# Total Income Amount (Month):15000.0    311
# 20000.0    293
# 30000.0    182
# 12000.0    133
# 10000.0    119
#           ...
# 20800.0      1
# 97000.0      1
# 5200.0       1
# 22770.0      1
# 9570.0       1
# Name: Total Income Amount (Month), Length: 185, dtype: int64
#
# age:39    89
# 40    88
# 38    78
# 30    72
# 33    71
# 35    68
# 41    67
# 36    67
# 31    66
# 32    64
# 45    63
# 37    63
# 34    61
# 43    58
# 29    55
# 42    54
# 47    54
# 28    52
# 44    50
# 27    47
# 46    46
# 26    45
# 52    41
# 48    35
# 53    34
# 51    33
# 49    32
# 55    30
# 25    27
# 24    26
# 50    26
# 57    24
# 56    24
# 54    22
# 23    22
# 58    20
# 60    17
# 22    14
# 62    14
# 61    13
# 59    10
# 63    10
# 65     6
# 66     6
# 67     6
# 68     4
# 64     4
# 21     3
# 69     2
# 70     1
# 71     1
# 72     1
# Name: age, dtype: int64
#
# System CAR Code (Daily):S1    937
# S2    844
# S3    105
# Name: System CAR Code (Daily), dtype: int64
#
# DPD:PL     1300
# NPL     529
# Name: DPD, dtype: int64
#
# Application Status:APPLICATION_COMPLETED    1886
# Name: Application Status, dtype: int64

# %% [markdown]
# ###Q1-Q3 Boxplot

# %%
cal_Q1 = df["age"].quantile(0.25)
cal_Q3 = df["age"].quantile(0.75)
cal_IQR = cal_Q3 - cal_Q1
cal_IQR
# Out:
# 14.0

# %%
lower_limit = cal_Q1 - 1.5 * cal_IQR
upper_limit = cal_Q3 + 1.5 * cal_IQR
print('lower:', lower_limit, 'upper:', upper_limit)
# Out:
# lower: 11.0 upper: 67.0

# %%
df = df[(df['age'] > lower_limit) & (df['age'] < upper_limit)]
df.boxplot(column=['age'])
# Out:
# <AxesSubplot:>

# %%
cal_Q1 = df["Total Income Amount (Month)"].quantile(0.25)
cal_Q3 = df["Total Income Amount (Month)"].quantile(0.75)
cal_IQR = cal_Q3 - cal_Q1
cal_IQR
# Out:
# 11000.0

# %%
lower_limit = cal_Q1 - 1.5 * cal_IQR
upper_limit = cal_Q3 + 1.5 * cal_IQR
print('lower:', lower_limit, 'upper:', upper_limit)
# Out:
# lower: -2500.0 upper: 41500.0

# %%
df = df[(df['Total Income Amount (Month)'] > lower_limit) & (df['Total Income Amount (Month)'] < upper_limit)]
df.boxplot(column=['Total Income Amount (Month)'])
# Out:
# <AxesSubplot:>

# %%
df['Total Income Amount (Month)'].max()
# Out:
# 40590.0

# %%
df['Total Income Amount (Month)'].min()
# Out:
# 5200.0

# %%
cal_Q1 = df["Total Income Amount (Month)"].quantile(0.25)
cal_Q3 = df["Total Income Amount (Month)"].quantile(0.75)
cal_IQR = cal_Q3 - cal_Q1
cal_IQR
# Out:
# 10990.0

# %%
lower_limit = cal_Q1 - 1.5 * cal_IQR
upper_limit = cal_Q3 + 1.5 * cal_IQR
print('lower:', lower_limit, 'upper:', upper_limit)
# Out:
# lower: -3385.0 upper: 40575.0

# %%
df = df[(df['Total Income Amount (Month)'] > lower_limit) & (df['Total Income Amount (Month)'] < upper_limit)]
df.boxplot(column=['Total Income Amount (Month)'])
# Out:
# <AxesSubplot:>

# %%
df['Total Income Amount (Month)'].min()
# Out:
# 5200.0

# %%
df['Total Income Amount (Month)'].max()
# Out:
# 40000.0

# %%
df.describe().round(2)
# Out:
#        Principal Approve Amount  Principal Amount  \
# count                   1748.00           1748.00
# mean                   75021.29          70099.16
# std                    92427.27          89647.53
# min                     3000.00              0.00
# 25%                    20000.00          18483.01
# 50%                    29000.00          27378.36
# 75%                   108625.00          97963.45
# max                   700000.00         700000.00
#
#        Repayment Tenor Month Number  Total Income Amount (Month)  \
# count                       1748.00                      1748.00
# mean                          35.87                     19132.15
# std                           15.93                      7845.95
# min                           12.00                      5200.00
# 25%                           24.00                     13087.50
# 50%                           36.00                     17600.00
# 75%                           48.00                     24060.00
# max                           60.00                     40000.00
#
#        Vehicle Release Year  Evaluation Amount      age  Vehicle Age
# count               1748.00            1748.00  1748.00      1748.00
# mean                2012.92          113207.89    39.57        10.08
# std                    5.06          135153.69     9.89         5.06
# min                 1994.00           10000.00    21.00         1.00
# 25%                 2010.00           33000.00    32.00         6.00
# 50%                 2013.00           41500.00    39.00        10.00
# 75%                 2017.00          186000.00    46.00        13.00
# max                 2022.00         1190000.00    66.00        29.00

# %%
cal_Q1 = df["Vehicle Age"].quantile(0.25)
cal_Q3 = df["Vehicle Age"].quantile(0.75)
cal_IQR = cal_Q3 - cal_Q1
cal_IQR
# Out:
# 7.0

# %%
lower_limit = cal_Q1 - 1.5 * cal_IQR
upper_limit = cal_Q3 + 1.5 * cal_IQR
print('lower:', lower_limit, 'upper:', upper_limit)
# Out:
# lower: -4.5 upper: 23.5

# %%
df = df[(df['Vehicle Age'] > lower_limit) & (df['Vehicle Age'] < upper_limit)]
df.boxplot(column=['Vehicle Age'])
# Out:
# <AxesSubplot:>

# %%
df.describe().round(2)
# Out:
#        Principal Approve Amount  Principal Amount  \
# count                   1731.00           1731.00
# mean                   75516.65          70564.03
# std                    92742.46          89960.14
# min                     3000.00              0.00
# 25%                    20000.00          18466.68
# 50%                    29000.00          27403.23
# 75%                   110000.00          99855.58
# max                   700000.00         700000.00
#
#        Repayment Tenor Month Number  Total Income Amount (Month)  \
# count                       1731.00                      1731.00
# mean                          35.95                     19124.49
# std                           15.96                      7842.22
# min                           12.00                      5200.00
# 25%                           24.00                     13190.00
# 50%                           36.00                     17500.00
# 75%                           48.00                     24000.00
# max                           60.00                     40000.00
#
#        Vehicle Release Year  Evaluation Amount      age  Vehicle Age
# count               1731.00            1731.00  1731.00      1731.00
# mean                2013.08          113463.26    39.54         9.92
# std                    4.81          135773.13     9.90         4.81
# min                 2000.00           10000.00    21.00         1.00
# 25%                 2010.00           33000.00    32.00         6.00
# 50%                 2013.00           41000.00    39.00        10.00
# 75%                 2017.00          190000.00    46.00        13.00
# max                 2022.00         1190000.00    66.00        23.00

# %% [markdown]
# ###Data Visualize

# %% [markdown]
# ####Categorical

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1731 entries, 0 to 43073
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Application Number             1731 non-null   object
#  1   Principal Approve Amount       1731 non-null   float64
#  2   Principal Amount               1731 non-null   float64
#  3   Repayment Tenor Month Number   1731 non-null   int32
#  4   Gender                         1731 non-null   object
#  5   DOB                            1731 non-null   datetime64[ns]
#  6   Occupation Description         1731 non-null   object
#  7   Total Income Amount (Month)    1731 non-null   float64
#  8   Collateral Type Code           1731 non-null   object
#  9   Vehicle Brand                  1731 non-null   object
#  10  Vehicle Model                  1731 non-null   object
#  11  Vehicle Release Year           1731 non-null   int64
#  12  Vehicle Sub Model              1731 non-null   object
#  13  Evaluation Amount              1731 non-null   int64
#  14  System CAR Code (Daily)        1731 non-null   object
#  15  System CAR Code Date           1731 non-null   datetime64[ns]
#  16  Final CAR Code Previous Month  1731 non-null   object
#  17  DPD                            1677 non-null   category
#  18  Application Status             1731 non-null   object
#  19  age                            1731 non-null   int64
#  20  Vehicle Age                    1731 non-null   int64
# dtypes: category(1), datetime64[ns](2), float64(3), int32(1), int64(4), object(10)
# memory usage: 279.0+ KB

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['Gender'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=13

# %%
plt.figure(figsize=(25,15))
sns.countplot(df['Occupation Description'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Occupation Description', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['Vehicle Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Vehicle Age', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['Collateral Type Code'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Collateral Type Code', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['Vehicle Brand'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Vehicle Brand', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['System CAR Code (Daily)'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='System CAR Code (Daily)', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Application Status'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Application Status', ylabel='count'>

# %% [markdown]
# ####numerical

# %%
plt.figure(figsize=(15,10))
sns.distplot(df['age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
plt.figure(figsize=(15,10))
sns.distplot(df['Principal Amount'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Principal Amount', ylabel='Density'>

# %%
plt.figure(figsize=(15,10))
sns.distplot(df['Repayment Tenor Month Number'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Repayment Tenor Month Number', ylabel='Density'>

# %%
plt.figure(figsize=(15,10))
sns.distplot(df['Total Income Amount (Month)'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total Income Amount (Month)', ylabel='Density'>

# %%
train_df = df.drop(columns=['Application Number']) ## Dropping Application Number
categorical_columns = ['Gender','Occupation Description','Vehicle Age','Collateral Type Code','Vehicle Brand','System CAR Code (Daily)','age','Application Status']

print(categorical_columns)
numerical_columns = ['age','Principal Amount', 'Repayment Tenor Month Number','Total Income Amount (Month)']
print(numerical_columns)
# Out:
# ['Gender', 'Occupation Description', 'Vehicle Age', 'Collateral Type Code', 'Vehicle Brand', 'System CAR Code (Daily)', 'age', 'Application Status']
# ['age', 'Principal Amount', 'Repayment Tenor Month Number', 'Total Income Amount (Month)']

# %%
### Data Visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt


fig,axes = plt.subplots(4,2,figsize=(30,15))
for idx,cat_col in enumerate(categorical_columns):
    row,col = idx//2,idx%2
    sns.countplot(x=cat_col,data=train_df,hue='DPD',ax=axes[row,col])


#plt.subplots_adjust(hspace=1)

# %%
fig,axes = plt.subplots(1,3,figsize=(17,5))
for idx,cat_col in enumerate(numerical_columns):
    sns.boxplot(y=cat_col,data=train_df,x='DPD',ax=axes[idx])

print(train_df[numerical_columns].describe())
plt.subplots_adjust(hspace=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [102], in <cell line: 2>()
#       1 fig,axes = plt.subplots(1,3,figsize=(17,5))
#       2 for idx,cat_col in enumerate(numerical_columns):
# ----> 3     sns.boxplot(y=cat_col,data=train_df,x='DPD',ax=axes[idx])
#       5 print(train_df[numerical_columns].describe())
#       6 plt.subplots_adjust(hspace=1)
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
df.columns
# Out:
# Index(['Application Number', 'Principal Approve Amount', 'Principal Amount',
#        'Repayment Tenor Month Number', 'Gender', 'DOB',
#        'Occupation Description', 'Total Income Amount (Month)',
#        'Collateral Type Code', 'Vehicle Brand', 'Vehicle Model',
#        'Vehicle Release Year', 'Vehicle Sub Model', 'Evaluation Amount',
#        'System CAR Code (Daily)', 'System CAR Code Date',
#        'Final CAR Code Previous Month', 'DPD', 'Application Status', 'age',
#        'Vehicle Age'],
#       dtype='object')

# %%
cols = ['Principal Approve Amount','Principal Amount','Total Income Amount (Month)','Repayment Tenor Month Number','age','Vehicle Age']

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20,9))
ax = ax.ravel()
for i, col in enumerate(cols):
    sns.violinplot(x='DPD', y=col, data=df, ax=ax[i])

# %% [markdown]
# ###correlation matrix

# %%
corr = df.corr()
corr
# Out:
#                               Principal Approve Amount  Principal Amount  \
# Principal Approve Amount                      1.000000          0.932881
# Principal Amount                              0.932881          1.000000
# Repayment Tenor Month Number                  0.754932          0.719126
# Total Income Amount (Month)                   0.382416          0.370169
# Vehicle Release Year                         -0.184249         -0.196166
# Evaluation Amount                             0.945270          0.882780
# age                                           0.072775          0.070239
# Vehicle Age                                   0.184249          0.196166
#
#                               Repayment Tenor Month Number  \
# Principal Approve Amount                          0.754932
# Principal Amount                                  0.719126
# Repayment Tenor Month Number                      1.000000
# Total Income Amount (Month)                       0.273081
# Vehicle Release Year                             -0.286990
# Evaluation Amount                                 0.713151
# age                                               0.043647
# Vehicle Age                                       0.286990
#
#                               Total Income Amount (Month)  \
# Principal Approve Amount                         0.382416
# Principal Amount                                 0.370169
# Repayment Tenor Month Number                     0.273081
# Total Income Amount (Month)                      1.000000
# Vehicle Release Year                            -0.088843
# Evaluation Amount                                0.393912
# age                                              0.097974
# Vehicle Age                                      0.088843
#
#                               Vehicle Release Year  Evaluation Amount  \
# Principal Approve Amount                 -0.184249           0.945270
# Principal Amount                         -0.196166           0.882780
# Repayment Tenor Month Number             -0.286990           0.713151
# Total Income Amount (Month)              -0.088843           0.393912
# Vehicle Release Year                      1.000000          -0.204930
# Evaluation Amount                        -0.204930           1.000000
# age                                      -0.148019           0.086633
# Vehicle Age                              -1.000000           0.204930
#
#                                    age  Vehicle Age
# Principal Approve Amount      0.072775     0.184249
# Principal Amount              0.070239     0.196166
# Repayment Tenor Month Number  0.043647     0.286990
# Total Income Amount (Month)   0.097974     0.088843
# Vehicle Release Year         -0.148019    -1.000000
# Evaluation Amount             0.086633     0.204930
# age                           1.000000     0.148019
# Vehicle Age                   0.148019     1.000000

# %%
df.describe().round(2)
# Out:
#        Principal Approve Amount  Principal Amount  \
# count                   1731.00           1731.00
# mean                   75516.65          70564.03
# std                    92742.46          89960.14
# min                     3000.00              0.00
# 25%                    20000.00          18466.68
# 50%                    29000.00          27403.23
# 75%                   110000.00          99855.58
# max                   700000.00         700000.00
#
#        Repayment Tenor Month Number  Total Income Amount (Month)  \
# count                       1731.00                      1731.00
# mean                          35.95                     19124.49
# std                           15.96                      7842.22
# min                           12.00                      5200.00
# 25%                           24.00                     13190.00
# 50%                           36.00                     17500.00
# 75%                           48.00                     24000.00
# max                           60.00                     40000.00
#
#        Vehicle Release Year  Evaluation Amount      age  Vehicle Age
# count               1731.00            1731.00  1731.00      1731.00
# mean                2013.08          113463.26    39.54         9.92
# std                    4.81          135773.13     9.90         4.81
# min                 2000.00           10000.00    21.00         1.00
# 25%                 2010.00           33000.00    32.00         6.00
# 50%                 2013.00           41000.00    39.00        10.00
# 75%                 2017.00          190000.00    46.00        13.00
# max                 2022.00         1190000.00    66.00        23.00

# %% [markdown]
# #Modeling

# %% [markdown]
# ###Drop Columns ที่ไม่ใช้

# %%
df.columns
# Out:
# Index(['Application Number', 'Principal Approve Amount', 'Principal Amount',
#        'Repayment Tenor Month Number', 'Gender', 'DOB',
#        'Occupation Description', 'Total Income Amount (Month)',
#        'Collateral Type Code', 'Vehicle Brand', 'Vehicle Model',
#        'Vehicle Release Year', 'Vehicle Sub Model', 'Evaluation Amount',
#        'System CAR Code (Daily)', 'System CAR Code Date',
#        'Final CAR Code Previous Month', 'DPD', 'Application Status', 'age',
#        'Vehicle Age'],
#       dtype='object')

# %%
df2 = df.copy()

# %%
cols = ['Application Number','DOB','Application Status']
df2 = df2.drop(columns=cols, axis=1)

# %%
df2.head(2)
# Out:
#     Principal Approve Amount  Principal Amount  Repayment Tenor Month Number  \
# 0                     7500.0              0.00                            12
# 10                   30000.0          26618.83                            24
#
#    Gender Occupation Description  Total Income Amount (Month)  \
# 0       M          พนักงานบริษัท                      10000.0
# 10      M                  อื่นๆ                      40000.0
#
#    Collateral Type Code Vehicle Brand  Vehicle Model  Vehicle Release Year  \
# 0                    PU        TOYOTA  SPORT CRUISER                  2002
# 10                  CAR     CHEVROLET           AVEO                  2012
#
#    Vehicle Sub Model  Evaluation Amount System CAR Code (Daily)  \
# 0                 EP             225500                      S1
# 10                BT             121000                      S1
#
#    System CAR Code Date Final CAR Code Previous Month DPD  age  Vehicle Age
# 0            2022-12-26                            S1  PL   31           21
# 10           2022-06-21                            S1  PL   29           11

# %% [markdown]
# ###LabelEncoder

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1686 entries, 0 to 43073
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Principal Approve Amount       1686 non-null   float64
#  1   Principal Amount               1686 non-null   float64
#  2   Repayment Tenor Month Number   1686 non-null   int32
#  3   Gender                         1686 non-null   object
#  4   Occupation Description         1686 non-null   object
#  5   Total Income Amount (Month)    1686 non-null   float64
#  6   Collateral Type Code           1686 non-null   object
#  7   Vehicle Brand                  1686 non-null   object
#  8   Vehicle Model                  1686 non-null   object
#  9   Vehicle Release Year           1686 non-null   int32
#  10  Vehicle Sub Model              1686 non-null   object
#  11  Evaluation Amount              1686 non-null   int64
#  12  System CAR Code (Daily)        1686 non-null   object
#  13  System CAR Code Date           1686 non-null   datetime64[ns]
#  14  Final CAR Code Previous Month  1686 non-null   object
#  15  DPD                            1686 non-null   category
#  16  age                            1686 non-null   int64
#  17  Vehicle Age                    1686 non-null   int64
# dtypes: category(1), datetime64[ns](1), float64(3), int32(2), int64(3), object(8)
# memory usage: 290.2+ KB

# %%
from sklearn.preprocessing import LabelEncoder
#cols = ['Gender','Occupation Description','Collateral Type Code','Vehicle Brand','Vehicle Model']
cols = ['Occupation Description','Collateral Type Code','Vehicle Brand','Vehicle Model']

le = LabelEncoder()
for col in cols:
    df2[col] = le.fit_transform(df2[col])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\_encode.py:132, in _unique_python(values, return_inverse)
#     130 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 132 uniques = sorted(uniques_set)
#     133 uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [113], in <cell line: 6>()
#       5 le = LabelEncoder()
#       6 for col in cols:
# ----> 7     df2[col] = le.fit_transform(df2[col])
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:117, in LabelEncoder.fit_transform(self, y)
#     105 """Fit label encoder and return encoded labels.
#     106
#     107 Parameters
#    (...)
#     114 y : array-like of shape (n_samples,)
#     115 """
#     116 y = column_or_1d(y, warn=True)
# --> 117 self.classes_, y = _unique(y, return_inverse=True)
#     118 return y
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\_encode.py:31, in _unique(values, return_inverse)
#       8 """Helper function to find unique values with support for python objects.
#       9
#      10 Uses pure python method for object dtype, and numpy method for
#    (...)
#      28     Only provided if `return_inverse` is True.
#      29 """
#      30 if values.dtype == object:
# ---> 31     return _unique_python(values, return_inverse=return_inverse)
#      32 # numerical
#      33 out = np.unique(values, return_inverse=return_inverse)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\_encode.py:138, in _unique_python(values, return_inverse)
#     135 except TypeError:
#     136     types = sorted(t.__qualname__
#     137                    for t in set(type(v) for v in values))
# --> 138     raise TypeError("Encoders require their input to be uniformly "
#     139                     f"strings or numbers. Got {types}")
#     141 if return_inverse:
#     142     return uniques, _map_to_integer(values, uniques)
#
# TypeError: Encoders require their input to be uniformly strings or numbers. Got ['int', 'str']

# %%
df2.head(5)
# Out:
#     Principal Approve Amount  Principal Amount  Repayment Tenor Month Number  \
# 0                     7500.0              0.00                            12
# 10                   30000.0          26618.83                            24
# 22                   20000.0          18434.00                            12
# 59                  165000.0              0.00                            60
# 61                   28000.0          26483.19                            24
#
#     Gender  Occupation Description  Total Income Amount (Month)  \
# 0        1                       4                      10000.0
# 10       1                       8                      40000.0
# 22       1                       8                      15000.0
# 59       1                       0                      30000.0
# 61       0                       8                      15000.0
#
#     Collateral Type Code  Vehicle Brand  Vehicle Model  Vehicle Release Year  \
# 0                      2             17  SPORT CRUISER                  2002
# 10                     0              1           AVEO                  2012
# 22                     1              4      WAVE 110I                  2019
# 59                     0             17           VIOS                  2010
# 61                     1              4      DREAM 110                  2015
#
#    Vehicle Sub Model  Evaluation Amount System CAR Code (Daily)  \
# 0                 EP             225500                      S1
# 10                BT             121000                      S1
# 22                DB              34500                      S2
# 59                DZ             240000                      S1
# 61                CC              44000                      S2
#
#    System CAR Code Date Final CAR Code Previous Month  DPD  age  Vehicle Age
# 0            2022-12-26                            S1   PL   31           21
# 10           2022-06-21                            S1   PL   29           11
# 22           2023-01-10                            S3  NPL   29            4
# 59           2023-01-10                            S2  NPL   33           13
# 61           2022-11-27                            S1  NPL   34            8

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1731 entries, 0 to 43073
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Principal Approve Amount       1731 non-null   float64
#  1   Principal Amount               1731 non-null   float64
#  2   Repayment Tenor Month Number   1731 non-null   int32
#  3   Gender                         1731 non-null   int32
#  4   Occupation Description         1731 non-null   int64
#  5   Total Income Amount (Month)    1731 non-null   float64
#  6   Collateral Type Code           1731 non-null   int64
#  7   Vehicle Brand                  1731 non-null   int64
#  8   Vehicle Model                  1731 non-null   object
#  9   Vehicle Release Year           1731 non-null   int64
#  10  Vehicle Sub Model              1731 non-null   object
#  11  Evaluation Amount              1731 non-null   int64
#  12  System CAR Code (Daily)        1731 non-null   object
#  13  System CAR Code Date           1731 non-null   datetime64[ns]
#  14  Final CAR Code Previous Month  1731 non-null   object
#  15  DPD                            1677 non-null   category
#  16  age                            1731 non-null   int64
#  17  Vehicle Age                    1731 non-null   int64
# dtypes: category(1), datetime64[ns](1), float64(3), int32(2), int64(7), object(4)
# memory usage: 296.2+ KB

# %%
corr = df2.corr()
corr
# Out:
#                               Principal Approve Amount  Principal Amount  \
# Principal Approve Amount                      1.000000          0.932881
# Principal Amount                              0.932881          1.000000
# Repayment Tenor Month Number                  0.754932          0.719126
# Gender                                        0.031660          0.024950
# Occupation Description                       -0.066406         -0.061429
# Total Income Amount (Month)                   0.382416          0.370169
# Collateral Type Code                          0.268132          0.254419
# Vehicle Brand                                 0.238230          0.228390
# Vehicle Release Year                         -0.184249         -0.196166
# Evaluation Amount                             0.945270          0.882780
# age                                           0.072775          0.070239
# Vehicle Age                                   0.184249          0.196166
#
#                               Repayment Tenor Month Number    Gender  \
# Principal Approve Amount                          0.754932  0.031660
# Principal Amount                                  0.719126  0.024950
# Repayment Tenor Month Number                      1.000000  0.020882
# Gender                                            0.020882  1.000000
# Occupation Description                           -0.076693  0.136879
# Total Income Amount (Month)                       0.273081  0.032660
# Collateral Type Code                              0.108311  0.114619
# Vehicle Brand                                     0.183346  0.004303
# Vehicle Release Year                             -0.286990 -0.052629
# Evaluation Amount                                 0.713151  0.055640
# age                                               0.043647  0.023366
# Vehicle Age                                       0.286990  0.052629
#
#                               Occupation Description  \
# Principal Approve Amount                   -0.066406
# Principal Amount                           -0.061429
# Repayment Tenor Month Number               -0.076693
# Gender                                      0.136879
# Occupation Description                      1.000000
# Total Income Amount (Month)                -0.256552
# Collateral Type Code                        0.087957
# Vehicle Brand                              -0.088672
# Vehicle Release Year                        0.009696
# Evaluation Amount                          -0.045035
# age                                         0.032749
# Vehicle Age                                -0.009696
#
#                               Total Income Amount (Month)  \
# Principal Approve Amount                         0.382416
# Principal Amount                                 0.370169
# Repayment Tenor Month Number                     0.273081
# Gender                                           0.032660
# Occupation Description                          -0.256552
# Total Income Amount (Month)                      1.000000
# Collateral Type Code                             0.063263
# Vehicle Brand                                    0.131138
# Vehicle Release Year                            -0.088843
# Evaluation Amount                                0.393912
# age                                              0.097974
# Vehicle Age                                      0.088843
#
#                               Collateral Type Code  Vehicle Brand  \
# Principal Approve Amount                  0.268132       0.238230
# Principal Amount                          0.254419       0.228390
# Repayment Tenor Month Number              0.108311       0.183346
# Gender                                    0.114619       0.004303
# Occupation Description                    0.087957      -0.088672
# Total Income Amount (Month)               0.063263       0.131138
# Collateral Type Code                      1.000000       0.060364
# Vehicle Brand                             0.060364       1.000000
# Vehicle Release Year                     -0.019669      -0.184429
# Evaluation Amount                         0.259187       0.231468
# age                                       0.096878       0.082790
# Vehicle Age                               0.019669       0.184429
#
#                               Vehicle Release Year  Evaluation Amount  \
# Principal Approve Amount                 -0.184249           0.945270
# Principal Amount                         -0.196166           0.882780
# Repayment Tenor Month Number             -0.286990           0.713151
# Gender                                   -0.052629           0.055640
# Occupation Description                    0.009696          -0.045035
# Total Income Amount (Month)              -0.088843           0.393912
# Collateral Type Code                     -0.019669           0.259187
# Vehicle Brand                            -0.184429           0.231468
# Vehicle Release Year                      1.000000          -0.204930
# Evaluation Amount                        -0.204930           1.000000
# age                                      -0.148019           0.086633
# Vehicle Age                              -1.000000           0.204930
#
#                                    age  Vehicle Age
# Principal Approve Amount      0.072775     0.184249
# Principal Amount              0.070239     0.196166
# Repayment Tenor Month Number  0.043647     0.286990
# Gender                        0.023366     0.052629
# Occupation Description        0.032749    -0.009696
# Total Income Amount (Month)   0.097974     0.088843
# Collateral Type Code          0.096878     0.019669
# Vehicle Brand                 0.082790     0.184429
# Vehicle Release Year         -0.148019    -1.000000
# Evaluation Amount             0.086633     0.204930
# age                           1.000000     0.148019
# Vehicle Age                   0.148019     1.000000

# %%
corr = df2.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True, cmap="BuPu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###ทดลอง Feature Importance

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
df2.columns
# Out:
# Index(['Principal Approve Amount', 'Principal Amount',
#        'Repayment Tenor Month Number', 'Gender', 'Occupation Description',
#        'Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand',
#        'Vehicle Model', 'Vehicle Release Year', 'Vehicle Sub Model',
#        'Evaluation Amount', 'System CAR Code (Daily)', 'System CAR Code Date',
#        'Final CAR Code Previous Month', 'DPD', 'age', 'Vehicle Age'],
#       dtype='object')

# %%
df2.head(2)
# Out:
#     Principal Approve Amount  Principal Amount  Repayment Tenor Month Number  \
# 0                     7500.0              0.00                            12
# 10                   30000.0          26618.83                            24
#
#     Gender  Occupation Description  Total Income Amount (Month)  \
# 0        1                       4                      10000.0
# 10       1                       8                      40000.0
#
#     Collateral Type Code  Vehicle Brand  Vehicle Model  Vehicle Release Year  \
# 0                      2             17  SPORT CRUISER                  2002
# 10                     0              1           AVEO                  2012
#
#    Vehicle Sub Model  Evaluation Amount System CAR Code (Daily)  \
# 0                 EP             225500                      S1
# 10                BT             121000                      S1
#
#    System CAR Code Date Final CAR Code Previous Month DPD  age  Vehicle Age
# 0            2022-12-26                            S1  PL   31           21
# 10           2022-06-21                            S1  PL   29           11

# %%
df2.columns
# Out:
# Index(['Principal Approve Amount', 'Principal Amount',
#        'Repayment Tenor Month Number', 'Gender', 'Occupation Description',
#        'Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand',
#        'Vehicle Model', 'Vehicle Release Year', 'Vehicle Sub Model',
#        'Evaluation Amount', 'System CAR Code (Daily)', 'System CAR Code Date',
#        'Final CAR Code Previous Month', 'DPD', 'age', 'Vehicle Age'],
#       dtype='object')

# %%
#cols = ['Principal Approve Amount', 'Principal Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description', 'Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand','Vehicle Model', 'Vehicle Release Year', 'Vehicle Sub Model','System CAR Code (Daily)', 'System CAR Code Date','Final CAR Code Previous Month', 'DPD', 'age', 'Vehicle Age']
cols = ['Principal Approve Amount','Principal Amount','Repayment Tenor Month Number','Gender','Occupation Description','Total Income Amount (Month)','Collateral Type Code','Vehicle Brand','Vehicle Model','System CAR Code (Daily)','age','Vehicle Age']

# %%
X = df2[cols] #features
y = df2['DPD'] #label

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn import tree

# %%
model=DecisionTreeClassifier(criterion='entropy')

model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [126], in <cell line: 3>()
#       1 model=DecisionTreeClassifier(criterion='entropy')
# ----> 3 model.fit(X_train, y_train)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py:898, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     861 def fit(self, X, y, sample_weight=None, check_input=True,
#     862         X_idx_sorted="deprecated"):
#     863     """Build a decision tree classifier from the training set (X, y).
#     864
#     865     Parameters
#    (...)
#     895         Fitted estimator.
#     896     """
# --> 898     super().fit(
#     899         X, y,
#     900         sample_weight=sample_weight,
#     901         check_input=check_input,
#     902         X_idx_sorted=X_idx_sorted)
#     903     return self
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py:156, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     154 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     155 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 156 X, y = self._validate_data(X, y,
#     157                            validate_separately=(check_X_params,
#     158                                                 check_y_params))
#     159 if issparse(X):
#     160     X.sort_indices()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:430, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     424 if validate_separately:
#     425     # We need this because some estimators validate X and y
#     426     # separately, and in general, separately calling check_array()
#     427     # on X and y isn't equivalent to just calling check_X_y()
#     428     # :(
#     429     check_X_params, check_y_params = validate_separately
# --> 430     X = check_array(X, **check_X_params)
#     431     y = check_array(y, **check_y_params)
#     432 else:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      61 extra_args = len(args) - len(all_args)
#      62 if extra_args <= 0:
# ---> 63     return f(*args, **kwargs)
#      65 # extra_args > 0
#      66 args_msg = ['{}={}'.format(name, arg)
#      67             for name, arg in zip(kwonly_args[:extra_args],
#      68                                  args[-extra_args:])]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:616, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614         array = array.astype(dtype, casting="unsafe", copy=False)
#     615     else:
# --> 616         array = np.asarray(array, order=order, dtype=dtype)
#     617 except ComplexWarning as complex_warning:
#     618     raise ValueError("Complex data not supported\n"
#     619                      "{}\n".format(array)) from complex_warning
#
# File C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102, in asarray(a, dtype, order, like)
#      99 if like is not None:
#     100     return _asarray_with_like(a, dtype=dtype, order=order, like=like)
# --> 102 return array(a, dtype, copy=False, order=order)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:1899, in NDFrame.__array__(self, dtype)
#    1898 def __array__(self, dtype=None) -> np.ndarray:
# -> 1899     return np.asarray(self._values, dtype=dtype)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102, in asarray(a, dtype, order, like)
#      99 if like is not None:
#     100     return _asarray_with_like(a, dtype=dtype, order=order, like=like)
# --> 102 return array(a, dtype, copy=False, order=order)
#
# ValueError: could not convert string to float: 'WAVE 110 I'

# %%
X_train.columns
# Out:
# Index(['Principal Approve Amount', 'Principal Amount',
#        'Repayment Tenor Month Number', 'Gender', 'Occupation Description',
#        'Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand',
#        'Vehicle Model', 'System CAR Code (Daily)', 'age', 'Vehicle Age'],
#       dtype='object')

# %% [markdown]
# ###Feature Importance

# %%
model.feature_importances_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [153], in <cell line: 1>()
# ----> 1 model.feature_importances_
#
# File C:\Python38\lib\site-packages\sklearn\tree\_classes.py:666, in BaseDecisionTree.feature_importances_(self)
#     648 """Return the feature importances.
#     649
#     650 The importance of a feature is computed as the (normalized) total
#    (...)
#     662     (Gini importance).
#     663 """
#     664 check_is_fitted(self)
# --> 666 return self.tree_.compute_feature_importances()
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'tree_'

# %%
fs = pd.Series(model.feature_importances_, index=X_train.columns).sort_values(
    ascending=False
)
fs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [154], in <cell line: 1>()
# ----> 1 fs = pd.Series(model.feature_importances_, index=X_train.columns).sort_values(
#       2     ascending=False
#       3 )
#       4 fs
#
# File C:\Python38\lib\site-packages\sklearn\tree\_classes.py:666, in BaseDecisionTree.feature_importances_(self)
#     648 """Return the feature importances.
#     649
#     650 The importance of a feature is computed as the (normalized) total
#    (...)
#     662     (Gini importance).
#     663 """
#     664 check_is_fitted(self)
# --> 666 return self.tree_.compute_feature_importances()
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'tree_'

# %%
fs.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [155], in <cell line: 1>()
# ----> 1 fs.sum()
#
# NameError: name 'fs' is not defined

# %%
plt.figure(figsize=(15,10))
fs.plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [156], in <cell line: 2>()
#       1 plt.figure(figsize=(15,10))
# ----> 2 fs.plot(kind='barh')
#
# NameError: name 'fs' is not defined

# %%
corr = df2.corr()
corr
# Out:
#                               Principal Approve Amount  Principal Amount  \
# Principal Approve Amount                      1.000000          0.931363
# Principal Amount                              0.931363          1.000000
# Repayment Tenor Month Number                  0.752804          0.715496
# Gender                                        0.027212          0.019942
# Total Income Amount (Month)                   0.383094          0.369706
# Vehicle Release Year                         -0.175675         -0.187768
# Evaluation Amount                             0.942525          0.878700
# age                                           0.068690          0.067116
# Vehicle Age                                   0.175675          0.187768
#
#                               Repayment Tenor Month Number    Gender  \
# Principal Approve Amount                          0.752804  0.027212
# Principal Amount                                  0.715496  0.019942
# Repayment Tenor Month Number                      1.000000  0.012209
# Gender                                            0.012209  1.000000
# Total Income Amount (Month)                       0.270648  0.026826
# Vehicle Release Year                             -0.276956 -0.061112
# Evaluation Amount                                 0.710371  0.049848
# age                                               0.044856  0.031768
# Vehicle Age                                       0.276956  0.061112
#
#                               Total Income Amount (Month)  \
# Principal Approve Amount                         0.383094
# Principal Amount                                 0.369706
# Repayment Tenor Month Number                     0.270648
# Gender                                           0.026826
# Total Income Amount (Month)                      1.000000
# Vehicle Release Year                            -0.092193
# Evaluation Amount                                0.395475
# age                                              0.094605
# Vehicle Age                                      0.092193
#
#                               Vehicle Release Year  Evaluation Amount  \
# Principal Approve Amount                 -0.175675           0.942525
# Principal Amount                         -0.187768           0.878700
# Repayment Tenor Month Number             -0.276956           0.710371
# Gender                                   -0.061112           0.049848
# Total Income Amount (Month)              -0.092193           0.395475
# Vehicle Release Year                      1.000000          -0.198235
# Evaluation Amount                        -0.198235           1.000000
# age                                      -0.156491           0.085100
# Vehicle Age                              -1.000000           0.198235
#
#                                    age  Vehicle Age
# Principal Approve Amount      0.068690     0.175675
# Principal Amount              0.067116     0.187768
# Repayment Tenor Month Number  0.044856     0.276956
# Gender                        0.031768     0.061112
# Total Income Amount (Month)   0.094605     0.092193
# Vehicle Release Year         -0.156491    -1.000000
# Evaluation Amount             0.085100     0.198235
# age                           1.000000     0.156491
# Vehicle Age                   0.156491     1.000000

# %%
corr = df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True, cmap="BuPu")
# Out:
# <AxesSubplot:>

# %%
df2
# Out:
#        Principal Approve Amount  Principal Amount  \
# 0                       7500.00              0.00
# 10                     30000.00          26618.83
# 22                     20000.00          18434.00
# 59                    165000.00              0.00
# 61                     28000.00          26483.19
# ...                         ...               ...
# 40692                  12800.00          12448.22
# 41159                  22000.00          22000.00
# 42273                 210000.00         210000.00
# 43069                  31632.28          31632.28
# 43073                  22853.47          22853.47
#
#        Repayment Tenor Month Number  Gender Occupation Description  \
# 0                                12       1          พนักงานบริษัท
# 10                               24       1                  อื่นๆ
# 22                               12       1                  อื่นๆ
# 59                               60       1          STREET VENDOR
# 61                               24       0                  อื่นๆ
# ...                             ...     ...                    ...
# 40692                            36       0          พนักงานบริษัท
# 41159                            48       0                เกษตรกร
# 42273                            60       1          STREET VENDOR
# 43069                            48       0                  อื่นๆ
# 43073                            36       0          พนักงานบริษัท
#
#        Total Income Amount (Month) Collateral Type Code Vehicle Brand  \
# 0                          10000.0                   PU        TOYOTA
# 10                         40000.0                  CAR     CHEVROLET
# 22                         15000.0                   MC         HONDA
# 59                         30000.0                  CAR        TOYOTA
# 61                         15000.0                   MC         HONDA
# ...                            ...                  ...           ...
# 40692                      18000.0                   MC         HONDA
# 41159                      15000.0                   PU        TOYOTA
# 42273                      20000.0                  CAR         HONDA
# 43069                      10000.0                   MC         HONDA
# 43073                      10000.0                   MC           GPX
#
#        Vehicle Model  Vehicle Release Year Vehicle Sub Model  \
# 0      SPORT CRUISER                  2002                EP
# 10              AVEO                  2012                BT
# 22         WAVE 110I                  2019                DB
# 59              VIOS                  2010                DZ
# 61         DREAM 110                  2015                CC
# ...              ...                   ...               ...
# 40692     CLICK 110I                  2010                AE
# 41159    HILUX TIGER                  2003                CF
# 42273           CITY                  2013                AB
# 43069     WAVE 110 I                  2019                DS
# 43073      DEMON 150                  2019                AC
#
#        Evaluation Amount System CAR Code (Daily) System CAR Code Date  \
# 0                 225500                      S1           2022-12-26
# 10                121000                      S1           2022-06-21
# 22                 34500                      S2           2023-01-10
# 59                240000                      S1           2023-01-10
# 61                 44000                      S2           2022-11-27
# ...                  ...                     ...                  ...
# 40692              17000                      S1           2022-11-29
# 41159             219500                      S2           2022-11-30
# 42273             282500                      S2           2022-11-29
# 43069              43000                      S2           2022-11-28
# 43073              33500                      S2           2022-11-30
#
#       Final CAR Code Previous Month  DPD  age  Vehicle Age
# 0                                S1   PL   31           21
# 10                               S1   PL   29           11
# 22                               S3  NPL   29            4
# 59                               S2  NPL   33           13
# 61                               S1  NPL   34            8
# ...                             ...  ...  ...          ...
# 40692                            S1   PL   35           13
# 41159                            S2   PL   53           20
# 42273                            S2   PL   55           10
# 43069                            S2   PL   50            4
# 43073                            S2   PL   34            4
#
# [1686 rows x 18 columns]

# %% [markdown]
# #Evaluation

# %% [markdown]
# ###Drop Cplomns ที่ไม่ใช้ออก

# %%
cols = ['Principal Approve Amount','Vehicle Model', 'Vehicle Release Year', 'Vehicle Sub Model',
       'System CAR Code (Daily)',
       'System CAR Code Date', 'Final CAR Code Previous Month']
df2 = df2.drop(columns=cols, axis=1)
df2.head()
# Out:
#     Principal Amount  Repayment Tenor Month Number  Gender  \
# 0               0.00                            12       1
# 10          26618.83                            24       1
# 22          18434.00                            12       1
# 59              0.00                            60       1
# 61          26483.19                            24       0
#
#    Occupation Description  Total Income Amount (Month) Collateral Type Code  \
# 0           พนักงานบริษัท                      10000.0                   PU
# 10                  อื่นๆ                      40000.0                  CAR
# 22                  อื่นๆ                      15000.0                   MC
# 59          STREET VENDOR                      30000.0                  CAR
# 61                  อื่นๆ                      15000.0                   MC
#
#    Vehicle Brand  Evaluation Amount  DPD  age  Vehicle Age
# 0         TOYOTA             225500   PL   31           21
# 10     CHEVROLET             121000   PL   29           11
# 22         HONDA              34500  NPL   29            4
# 59        TOYOTA             240000  NPL   33           13
# 61         HONDA              44000  NPL   34            8

# %%
X = df2.drop(columns=['DPD'], axis=1)
y = df2['DPD']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)

# %%
from sklearn.model_selection import cross_val_score
def classify(model, x,y):
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)
    model.fit(x_train, y_train)
    print("Accuracy is : ", model.score(x_test, y_test)*100)
    #Cross Calidation
    #eg: cv-5, train-4, test-1
    score = cross_val_score(model, x, y, cv=5)
    print("Cross Validation is ", np.mean(score)*100)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1686 entries, 0 to 43073
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Principal Amount              1686 non-null   float64
#  1   Repayment Tenor Month Number  1686 non-null   int32
#  2   Gender                        1686 non-null   int32
#  3   Occupation Description        1686 non-null   object
#  4   Total Income Amount (Month)   1686 non-null   float64
#  5   Collateral Type Code          1686 non-null   object
#  6   Vehicle Brand                 1686 non-null   object
#  7   Evaluation Amount             1686 non-null   int64
#  8   DPD                           1686 non-null   category
#  9   age                           1686 non-null   int64
#  10  Vehicle Age                   1686 non-null   int64
# dtypes: category(1), float64(2), int32(2), int64(3), object(3)
# memory usage: 198.0+ KB

# %%
df2.isnull().sum()
# Out:
# Principal Amount                0
# Repayment Tenor Month Number    0
# Gender                          0
# Occupation Description          0
# Total Income Amount (Month)     0
# Collateral Type Code            0
# Vehicle Brand                   0
# Evaluation Amount               0
# DPD                             0
# age                             0
# Vehicle Age                     0
# dtype: int64

# %%
df2.dropna(subset=['DPD'], inplace=True)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model,X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [167], in <cell line: 3>()
#       1 from sklearn.linear_model import LogisticRegression
#       2 model = LogisticRegression()
# ----> 3 classify(model,X,y)
#
# Input In [163], in classify(model, x, y)
#       2 def classify(model, x,y):
#       3     x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)
# ----> 4     model.fit(x_train, y_train)
#       5     print("Accuracy is : ", model.score(x_test, y_test)*100)
#       6     #Cross Calidation
#       7     #eg: cv-5, train-4, test-1
#
# File C:\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1138, in LogisticRegression.fit(self, X, y, sample_weight)
#    1135 else:
#    1136     _dtype = [np.float64, np.float32]
# -> 1138 X, y = self._validate_data(
#    1139     X,
#    1140     y,
#    1141     accept_sparse="csr",
#    1142     dtype=_dtype,
#    1143     order="C",
#    1144     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1145 )
#    1146 check_classification_targets(y)
#    1147 self.classes_ = np.unique(y)
#
# File C:\Python38\lib\site-packages\sklearn\base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
#
# File C:\Python38\lib\site-packages\sklearn\utils\validation.py:1074, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1069         estimator_name = _check_estimator_name(estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
# -> 1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    1077     accept_large_sparse=accept_large_sparse,
#    1078     dtype=dtype,
#    1079     order=order,
#    1080     copy=copy,
#    1081     force_all_finite=force_all_finite,
#    1082     ensure_2d=ensure_2d,
#    1083     allow_nd=allow_nd,
#    1084     ensure_min_samples=ensure_min_samples,
#    1085     ensure_min_features=ensure_min_features,
#    1086     estimator=estimator,
#    1087     input_name="X",
#    1088 )
#    1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#
# File C:\Python38\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File C:\Python38\lib\site-packages\pandas\core\generic.py:2072, in NDFrame.__array__(self, dtype)
#    2071 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2072     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'พนักงานบริษัท'

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
classify(model,X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [168], in <cell line: 3>()
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 model = DecisionTreeClassifier()
# ----> 3 classify(model,X,y)
#
# Input In [163], in classify(model, x, y)
#       2 def classify(model, x,y):
#       3     x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)
# ----> 4     model.fit(x_train, y_train)
#       5     print("Accuracy is : ", model.score(x_test, y_test)*100)
#       6     #Cross Calidation
#       7     #eg: cv-5, train-4, test-1
#
# File C:\Python38\lib\site-packages\sklearn\tree\_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# File C:\Python38\lib\site-packages\sklearn\tree\_classes.py:172, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     170 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     171 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 172 X, y = self._validate_data(
#     173     X, y, validate_separately=(check_X_params, check_y_params)
#     174 )
#     175 if issparse(X):
#     176     X.sort_indices()
#
# File C:\Python38\lib\site-packages\sklearn\base.py:591, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     589 if "estimator" not in check_X_params:
#     590     check_X_params = {**default_check_params, **check_X_params}
# --> 591 X = check_array(X, input_name="X", **check_X_params)
#     592 if "estimator" not in check_y_params:
#     593     check_y_params = {**default_check_params, **check_y_params}
#
# File C:\Python38\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File C:\Python38\lib\site-packages\pandas\core\generic.py:2072, in NDFrame.__array__(self, dtype)
#    2071 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2072     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'พนักงานบริษัท'

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
model = RandomForestClassifier()
classify(model,X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [169], in <cell line: 3>()
#       1 from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
#       2 model = RandomForestClassifier()
# ----> 3 classify(model,X,y)
#
# Input In [163], in classify(model, x, y)
#       2 def classify(model, x,y):
#       3     x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)
# ----> 4     model.fit(x_train, y_train)
#       5     print("Accuracy is : ", model.score(x_test, y_test)*100)
#       6     #Cross Calidation
#       7     #eg: cv-5, train-4, test-1
#
# File C:\Python38\lib\site-packages\sklearn\ensemble\_forest.py:331, in BaseForest.fit(self, X, y, sample_weight)
#     329 if issparse(y):
#     330     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 331 X, y = self._validate_data(
#     332     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     333 )
#     334 if sample_weight is not None:
#     335     sample_weight = _check_sample_weight(sample_weight, X)
#
# File C:\Python38\lib\site-packages\sklearn\base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
#
# File C:\Python38\lib\site-packages\sklearn\utils\validation.py:1074, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1069         estimator_name = _check_estimator_name(estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
# -> 1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    1077     accept_large_sparse=accept_large_sparse,
#    1078     dtype=dtype,
#    1079     order=order,
#    1080     copy=copy,
#    1081     force_all_finite=force_all_finite,
#    1082     ensure_2d=ensure_2d,
#    1083     allow_nd=allow_nd,
#    1084     ensure_min_samples=ensure_min_samples,
#    1085     ensure_min_features=ensure_min_features,
#    1086     estimator=estimator,
#    1087     input_name="X",
#    1088 )
#    1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#
# File C:\Python38\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File C:\Python38\lib\site-packages\pandas\core\generic.py:2072, in NDFrame.__array__(self, dtype)
#    2071 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2072     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'พนักงานบริษัท'

# %%
model = ExtraTreesClassifier()
classify(model,X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [170], in <cell line: 2>()
#       1 model = ExtraTreesClassifier()
# ----> 2 classify(model,X,y)
#
# Input In [163], in classify(model, x, y)
#       2 def classify(model, x,y):
#       3     x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)
# ----> 4     model.fit(x_train, y_train)
#       5     print("Accuracy is : ", model.score(x_test, y_test)*100)
#       6     #Cross Calidation
#       7     #eg: cv-5, train-4, test-1
#
# File C:\Python38\lib\site-packages\sklearn\ensemble\_forest.py:331, in BaseForest.fit(self, X, y, sample_weight)
#     329 if issparse(y):
#     330     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 331 X, y = self._validate_data(
#     332     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     333 )
#     334 if sample_weight is not None:
#     335     sample_weight = _check_sample_weight(sample_weight, X)
#
# File C:\Python38\lib\site-packages\sklearn\base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
#
# File C:\Python38\lib\site-packages\sklearn\utils\validation.py:1074, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1069         estimator_name = _check_estimator_name(estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
# -> 1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    1077     accept_large_sparse=accept_large_sparse,
#    1078     dtype=dtype,
#    1079     order=order,
#    1080     copy=copy,
#    1081     force_all_finite=force_all_finite,
#    1082     ensure_2d=ensure_2d,
#    1083     allow_nd=allow_nd,
#    1084     ensure_min_samples=ensure_min_samples,
#    1085     ensure_min_features=ensure_min_features,
#    1086     estimator=estimator,
#    1087     input_name="X",
#    1088 )
#    1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#
# File C:\Python38\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File C:\Python38\lib\site-packages\pandas\core\generic.py:2072, in NDFrame.__array__(self, dtype)
#    2071 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2072     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'พนักงานบริษัท'

# %%
y_train.value_counts()
# Out:
# PL     820
# NPL    360
# Name: DPD, dtype: int64

# %%
df2.columns
# Out:
# Index(['Principal Amount', 'Repayment Tenor Month Number', 'Gender',
#        'Occupation Description', 'Total Income Amount (Month)',
#        'Collateral Type Code', 'Vehicle Brand', 'Evaluation Amount', 'DPD',
#        'age', 'Vehicle Age'],
#       dtype='object')

# %%
#X = df2[['Principal Amount','Outstanding Balance Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age']]
X = df2[['Principal Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age']]
y = df2['DPD']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =  train_test_split(X ,y ,test_size=0.2, random_state=0)
X_train.shape
# Out:
# (1348, 9)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(criterion='entropy')
classifier = model.fit(X_train,y_train)
classifier
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [175], in <cell line: 4>()
#       1 from sklearn.tree import DecisionTreeClassifier
#       3 model = DecisionTreeClassifier(criterion='entropy')
# ----> 4 classifier = model.fit(X_train,y_train)
#       5 classifier
#
# File C:\Python38\lib\site-packages\sklearn\tree\_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# File C:\Python38\lib\site-packages\sklearn\tree\_classes.py:172, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     170 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     171 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 172 X, y = self._validate_data(
#     173     X, y, validate_separately=(check_X_params, check_y_params)
#     174 )
#     175 if issparse(X):
#     176     X.sort_indices()
#
# File C:\Python38\lib\site-packages\sklearn\base.py:591, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     589 if "estimator" not in check_X_params:
#     590     check_X_params = {**default_check_params, **check_X_params}
# --> 591 X = check_array(X, input_name="X", **check_X_params)
#     592 if "estimator" not in check_y_params:
#     593     check_y_params = {**default_check_params, **check_y_params}
#
# File C:\Python38\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File C:\Python38\lib\site-packages\pandas\core\generic.py:2072, in NDFrame.__array__(self, dtype)
#    2071 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2072     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'STREET VENDOR'

# %%
#prediction
y_pred = classifier.predict(X_test)
from sklearn import metrics
#Accuracy
print('Accuracy Score:', metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [176], in <cell line: 2>()
#       1 #prediction
# ----> 2 y_pred = classifier.predict(X_test)
#       3 from sklearn import metrics
#       4 #Accuracy
#
# NameError: name 'classifier' is not defined

# %%
df2.columns
# Out:
# Index(['Principal Amount', 'Repayment Tenor Month Number', 'Gender',
#        'Occupation Description', 'Total Income Amount (Month)',
#        'Collateral Type Code', 'Vehicle Brand', 'Evaluation Amount', 'DPD',
#        'age', 'Vehicle Age'],
#       dtype='object')

# %%
from sklearn import tree
plt.figure(figsize=(40,25))
tree.plot_tree(classifier, 
                   #feature_names=['Principal Amount','Outstanding Balance Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age'],  
                   feature_names=['Principal Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age'],  
                   class_names=['NPL','PL'],
                   filled=True,node_ids=True,fontsize=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [178], in <cell line: 3>()
#       1 from sklearn import tree
#       2 plt.figure(figsize=(40,25))
# ----> 3 tree.plot_tree(classifier,
#       4                    #feature_names=['Principal Amount','Outstanding Balance Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age'],
#       5                    feature_names=['Principal Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age'],
#       6                    class_names=['NPL','PL'],
#       7                    filled=True,node_ids=True,fontsize=10)
#
# NameError: name 'classifier' is not defined

# %%
# Create Decision Tree classifer object
# Train Decision Tree Classifer
classifier = DecisionTreeClassifier(criterion="entropy", max_depth=4)
#Predict the response for test dataset
classifier = classifier.fit(X_train, y_train)
# Model Accuracy, how often is the classifier correct?
y_pred = classifier.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [179], in <cell line: 5>()
#       3 classifier = DecisionTreeClassifier(criterion="entropy", max_depth=4)
#       4 #Predict the response for test dataset
# ----> 5 classifier = classifier.fit(X_train, y_train)
#       6 # Model Accuracy, how often is the classifier correct?
#       7 y_pred = classifier.predict(X_test)
#
# File C:\Python38\lib\site-packages\sklearn\tree\_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# File C:\Python38\lib\site-packages\sklearn\tree\_classes.py:172, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     170 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     171 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 172 X, y = self._validate_data(
#     173     X, y, validate_separately=(check_X_params, check_y_params)
#     174 )
#     175 if issparse(X):
#     176     X.sort_indices()
#
# File C:\Python38\lib\site-packages\sklearn\base.py:591, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     589 if "estimator" not in check_X_params:
#     590     check_X_params = {**default_check_params, **check_X_params}
# --> 591 X = check_array(X, input_name="X", **check_X_params)
#     592 if "estimator" not in check_y_params:
#     593     check_y_params = {**default_check_params, **check_y_params}
#
# File C:\Python38\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File C:\Python38\lib\site-packages\pandas\core\generic.py:2072, in NDFrame.__array__(self, dtype)
#    2071 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2072     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'STREET VENDOR'

# %%
from sklearn import tree
fig = plt.figure(figsize=(40,25))
_ = tree.plot_tree(classifier, 
                   #feature_names=['Principal Amount','Outstanding Balance Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age'],  
                   feature_names=['Principal Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age'],
                   class_names=['NPL','PL'],
                   filled=True, fontsize=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [180], in <cell line: 3>()
#       1 from sklearn import tree
#       2 fig = plt.figure(figsize=(40,25))
# ----> 3 _ = tree.plot_tree(classifier,
#       4                    #feature_names=['Principal Amount','Outstanding Balance Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age'],
#       5                    feature_names=['Principal Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age'],
#       6                    class_names=['NPL','PL'],
#       7                    filled=True, fontsize=10)
#
# File C:\Python38\lib\site-packages\sklearn\tree\_export.py:195, in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     180 check_is_fitted(decision_tree)
#     182 exporter = _MPLTreeExporter(
#     183     max_depth=max_depth,
#     184     feature_names=feature_names,
#    (...)
#     193     fontsize=fontsize,
#     194 )
# --> 195 return exporter.export(decision_tree, ax=ax)
#
# File C:\Python38\lib\site-packages\sklearn\tree\_export.py:656, in _MPLTreeExporter.export(self, decision_tree, ax)
#     654 ax.clear()
#     655 ax.set_axis_off()
# --> 656 my_tree = self._make_tree(0, decision_tree.tree_, decision_tree.criterion)
#     657 draw_tree = buchheim(my_tree)
#     659 # important to make sure we're still
#     660 # inside the axis after drawing the box
#     661 # this makes sense because the width of a box
#     662 # is about the same as the distance between boxes
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'tree_'

# %%
import graphviz

# %%
dot_data = tree.export_graphviz(classifier, out_file=None,
                                #feature_names=['Principal Amount','Outstanding Balance Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age'],  
                                feature_names=['Principal Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age'],
                                class_names=['NPL','PL'],
                                filled=True, rounded=True,
                                special_characters=True)
graph = graphviz.Source(dot_data)
graph
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [182], in <cell line: 1>()
# ----> 1 dot_data = tree.export_graphviz(classifier, out_file=None,
#       2                                 #feature_names=['Principal Amount','Outstanding Balance Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age'],
#       3                                 feature_names=['Principal Amount','Repayment Tenor Month Number', 'Gender', 'Occupation Description','Total Income Amount (Month)', 'Collateral Type Code', 'Vehicle Brand', 'age', 'Vehicle Age'],
#       4                                 class_names=['NPL','PL'],
#       5                                 filled=True, rounded=True,
#       6                                 special_characters=True)
#       7 graph = graphviz.Source(dot_data)
#       8 graph
#
# File C:\Python38\lib\site-packages\sklearn\tree\_export.py:889, in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     870     out_file = StringIO()
#     872 exporter = _DOTTreeExporter(
#     873     out_file=out_file,
#     874     max_depth=max_depth,
#    (...)
#     887     fontname=fontname,
#     888 )
# --> 889 exporter.export(decision_tree)
#     891 if return_string:
#     892     return exporter.out_file.getvalue()
#
# File C:\Python38\lib\site-packages\sklearn\tree\_export.py:451, in _DOTTreeExporter.export(self, decision_tree)
#     446 def export(self, decision_tree):
#     447     # Check length of feature_names before getting into the tree node
#     448     # Raise error if length of feature_names does not match
#     449     # n_features_in_ in the decision_tree
#     450     if self.feature_names is not None:
# --> 451         if len(self.feature_names) != decision_tree.n_features_in_:
#     452             raise ValueError(
#     453                 "Length of feature_names, %d does not match number of features, %d"
#     454                 % (len(self.feature_names), decision_tree.n_features_in_)
#     455             )
#     456     # each part writes to out_file
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'n_features_in_'

# %% [markdown]
# #Deployment

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
cm = confusion_matrix(y_test, y_pred)
print('Confusion matrix : \n',cm)

cr = classification_report(y_test, y_pred)
print('Classification report  \n',cr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [183], in <cell line: 3>()
#       1 from sklearn.metrics import confusion_matrix
#       2 from sklearn.metrics import classification_report
# ----> 3 cm = confusion_matrix(y_test, y_pred)
#       4 print('Confusion matrix : \n',cm)
#       6 cr = classification_report(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix, plot_roc_curve
plot_confusion_matrix(model, X_test, y_test, cmap='Blues', values_format='d')
